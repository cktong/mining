# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 2: Mining Facebook: Analyzing Fan Pages, Examining Friendships, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Facebook API Access
#
# Facebook implements OAuth 2.0 as its standard authentication mechanism, but provides a convenient way for you to get an _access token_ for development purposes, and we'll opt to take advantage of that convenience in this notebook. For details on implementing an OAuth flow with Facebook (all from within IPython Notebook), see the \_AppendixB notebook from the [IPython Notebook Dashboard](/).
#
# For this first example, login to your Facebook account and go to https://developers.facebook.com/tools/explorer/ to obtain and set permissions for an access token that you will need to define in the code cell defining the ACCESS_TOKEN variable below.
#
# Be sure to explore the permissions that are available by clicking on the "Get Access Token" button that's on the page and exploring all of the tabs available. For example, you will need to set the "friends_likes" option under the "Friends Data Permissions" since this permission is used by the script below but is not a basic permission and is not enabled by default.
#
# <img src="files/resources/ch02-facebook/images/FB_GraphExplorer_perms.png" width="300px" /><br />

# %%
# Copy and paste in the value you just got from the inline frame into this variable and execute this cell.
# Keep in mind that you could have just gone to https://developers.facebook.com/tools/access_token/
# and retrieved the "User Token" value from the Access Token Tool

ACCESS_TOKEN = 'CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD'

# %% [markdown]
# ## Example 1. Making Graph API requests over HTTP

# %%
import requests # pip install requests
import json

base_url = 'https://graph.facebook.com/me'

# Get 10 likes for 10 friends
fields = 'id,name,friends.limit(10).fields(likes.limit(10))'

url = '%s?fields=%s&access_token=%s' % \
    (base_url, fields, ACCESS_TOKEN,)

# This API is HTTP-based and could be requested in the browser,
# with a command line utlity like curl, or using just about
# any programming language by making a request to the URL.
# Click the hyperlink that appears in your notebook output
# when you execute this code cell to see for yourself...
print url

# Interpret the response as JSON and convert back
# to Python data structures
content = requests.get(url).json()

# Pretty-print the JSON and display it
print json.dumps(content, indent=1)
# Out:
# https://graph.facebook.com/me?fields=id,name,friends.limit(10).fields(likes.limit(10))&access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD
# {
#  "friends": {
#   "paging": {
#    "next": "https://graph.facebook.com/v1.0/10203193585293342/friends?limit=10&fields=likes.limit%2810%29&access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD&offset=10&__after_id=enc_AeyUG2BcQkQ8r2PxfcVNS9NBU2n__SbfHNpqvr-jfWF6FrPr5twVvLKkHsXUap42A1QA8qeml9EFjG0y-pTmO7_a"
#   },
#   "data": [
#    {
#     "id": "558857930",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTA5NTkyNjU1NzM0NDM2",
#        "before": "MTk5MDYyMDIzNDkxMDIx"
#       },
#       "next": "https://graph.facebook.com/v1.0/558857930/likes?limit=10&access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD&after=MTA5NTkyNjU1NzM0NDM2"
#      },
#      "data": [
#       {
#        "category": "Non-profit organization",
#        "created_time": "2013-12-04T22:08:03+0000",
#        "name": "Breast Intentions",
#        "category_list": [
#         {
#          "id": "2603",
#          "name": "Non-Profit Organization"
#         }
#        ],
#        "id": "199062023491021"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2013-09-30T11:30:23+0000",
#        "name": "Virgin Mobile USA",
#        "id": "176824455678893"
#       },
#       {
#        "category": "Reference website",
#        "created_time": "2013-08-08T14:34:42+0000",
#        "name": "Talk To Me In Korean",
#        "id": "436808480033"
#       },
#       {
#        "category": "Computers/technology",
#        "created_time": "2013-07-11T04:55:12+0000",
#        "name": "Jisun Jung Fan Club",
#        "id": "158604414323256"
#       },
#       {
#        "category": "Community",
#        "created_time": "2013-06-11T02:12:53+0000",
#        "name": "Lee Gao Fan Club",
#        "id": "477767132305174"
#       },
#       {
#        "category": "Computers/technology",
#        "created_time": "2012-09-02T18:38:51+0000",
#        "name": "PennApps",
#        "id": "103140939743548"
#       },
#       {
#        "category": "Tv show",
#        "created_time": "2012-06-11T20:09:44+0000",
#        "name": "Shaq Vs.",
#        "id": "109392885745184"
#       },
#       {
#        "category": "Community organization",
#        "created_time": "2012-05-08T15:30:59+0000",
#        "name": "B.L.U.E. Shuttle",
#        "id": "221708267944720"
#       },
#       {
#        "category": "Musical genre",
#        "created_time": "2012-04-08T02:25:37+0000",
#        "name": "KPop",
#        "id": "110376505656631"
#       },
#       {
#        "category": "Musical genre",
#        "created_time": "2012-04-08T02:25:36+0000",
#        "name": "Dubstep",
#        "id": "109592655734436"
#       }
#      ]
#     }
#    },
#    {
#     "id": "616994476",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MjE4NzI0ODk0OTY=",
#        "before": "NDU3NDY4MDE0MzIxNjQz"
#       }
#      },
#      "data": [
#       {
#        "category": "Community",
#        "created_time": "2013-03-11T15:18:45+0000",
#        "name": "Sick Spits",
#        "id": "457468014321643"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2013-01-31T07:48:05+0000",
#        "name": "Kaotonix",
#        "id": "344615285603931"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2012-05-20T21:56:05+0000",
#        "name": "The Skunkadelics",
#        "id": "321144881231365"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2009-10-11T02:42:35+0000",
#        "name": "Modest Mouse",
#        "id": "21872489496"
#       }
#      ]
#     }
#    },
#    {
#     "id": "618311320"
#    },
#    {
#     "id": "637864202",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "NDg0MTI2MjI4Mzc5NTY4",
#        "before": "MjQ3NTI2ODE1MjcyNjY3"
#       },
#       "next": "https://graph.facebook.com/v1.0/637864202/likes?limit=10&access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD&after=NDg0MTI2MjI4Mzc5NTY4"
#      },
#      "data": [
#       {
#        "category": "Restaurant/cafe",
#        "created_time": "2014-06-02T19:45:46+0000",
#        "name": "Stardust Video & Coffee",
#        "category_list": [
#         {
#          "id": "273819889375819",
#          "name": "Restaurant"
#         },
#         {
#          "id": "110290705711626",
#          "name": "Bar"
#         },
#         {
#          "id": "150432221681325",
#          "name": "DVD & Video Store"
#         }
#        ],
#        "id": "247526815272667"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2014-05-27T05:40:41+0000",
#        "name": "Winter Park Beer Company",
#        "category_list": [
#         {
#          "id": "144535972273084",
#          "name": "Brewery"
#         }
#        ],
#        "id": "470466629646026"
#       },
#       {
#        "category": "Arts/entertainment/nightlife",
#        "created_time": "2014-05-22T15:58:48+0000",
#        "name": "The Falcon",
#        "category_list": [
#         {
#          "id": "110290705711626",
#          "name": "Bar"
#         }
#        ],
#        "id": "108430985905446"
#       },
#       {
#        "category": "Food/grocery",
#        "created_time": "2014-05-06T19:17:39+0000",
#        "name": "Euro Bake World",
#        "category_list": [
#         {
#          "id": "187827497907070",
#          "name": "Bakery"
#         }
#        ],
#        "id": "290762214413133"
#       },
#       {
#        "category": "Organization",
#        "created_time": "2014-04-22T23:28:01+0000",
#        "name": "1 Million Cups Orlando",
#        "category_list": [
#         {
#          "id": "198503866828628",
#          "name": "Organization"
#         }
#        ],
#        "id": "663410337003729"
#       },
#       {
#        "category": "Artist",
#        "created_time": "2014-04-07T00:17:40+0000",
#        "name": "Brandon Brown Photography",
#        "id": "418775781563286"
#       },
#       {
#        "category": "Company",
#        "created_time": "2014-04-05T15:42:25+0000",
#        "name": "It's Apples",
#        "id": "201635836664"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2014-04-04T03:34:59+0000",
#        "name": "Envy Labs",
#        "category_list": [
#         {
#          "id": "2500",
#          "name": "Local Business"
#         }
#        ],
#        "id": "172274799491370"
#       },
#       {
#        "category": "Food/grocery",
#        "created_time": "2014-04-01T03:20:20+0000",
#        "name": "Isle of Salsa",
#        "category_list": [
#         {
#          "id": "150108431712141",
#          "name": "Food & Grocery"
#         }
#        ],
#        "id": "154615481217108"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-03-29T23:35:43+0000",
#        "name": "Smart Love",
#        "id": "484126228379568"
#       }
#      ]
#     }
#    },
#    {
#     "id": "645660973",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTIxOTMwNDk3ODYxNzUz",
#        "before": "MTI1NjQ3MzEyMTkx"
#       },
#       "next": "https://graph.facebook.com/v1.0/645660973/likes?limit=10&access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD&after=MTIxOTMwNDk3ODYxNzUz"
#      },
#      "data": [
#       {
#        "category": "Musician/band",
#        "created_time": "2014-05-11T08:29:39+0000",
#        "name": "The White Panda",
#        "id": "125647312191"
#       },
#       {
#        "category": "Computers/technology",
#        "created_time": "2014-04-24T19:46:32+0000",
#        "name": "Urban Engines",
#        "id": "530504817014740"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2013-11-14T05:11:22+0000",
#        "name": "Cal Blueprint",
#        "id": "122567184578842"
#       },
#       {
#        "category": "Software",
#        "created_time": "2013-09-17T05:23:54+0000",
#        "name": "Metrohop",
#        "id": "332699670199049"
#       },
#       {
#        "category": "Politician",
#        "created_time": "2013-03-18T06:22:42+0000",
#        "name": "Caitlin Quinn for ASUC Senate",
#        "id": "252214464914676"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2013-02-16T03:37:55+0000",
#        "name": "Hunger Games Page",
#        "id": "140504009302351"
#       },
#       {
#        "category": "Movie",
#        "created_time": "2012-10-28T07:54:03+0000",
#        "name": "Cloud Atlas",
#        "id": "276594512350797"
#       },
#       {
#        "category": "Community",
#        "created_time": "2012-09-15T17:48:52+0000",
#        "name": "Queer at Berkeley",
#        "id": "370946809638662"
#       },
#       {
#        "category": "Video game",
#        "created_time": "2012-05-21T19:23:12+0000",
#        "name": "Portal 2",
#        "id": "103794622992415"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2012-05-21T19:22:24+0000",
#        "name": "One Direction",
#        "id": "121930497861753"
#       }
#      ]
#     }
#    },
#    {
#     "id": "718469406",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "NDE4MDk1NjYxNTc1ODAy",
#        "before": "Njc4NDQ3NTEyMjEzMzAz"
#       },
#       "next": "https://graph.facebook.com/v1.0/718469406/likes?limit=10&access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD&after=NDE4MDk1NjYxNTc1ODAy"
#      },
#      "data": [
#       {
#        "category": "Community",
#        "created_time": "2014-05-26T23:20:12+0000",
#        "name": "\u90a3\u4e9b\u611f\u4eba\u7684\u6642\u523b",
#        "id": "678447512213303"
#       },
#       {
#        "category": "Shopping/retail",
#        "created_time": "2014-03-27T08:11:29+0000",
#        "name": "Amber in Fantasy",
#        "category_list": [
#         {
#          "id": "200600219953504",
#          "name": "Shopping & Retail"
#         }
#        ],
#        "id": "1467930016764431"
#       },
#       {
#        "category": "Community",
#        "created_time": "2013-12-14T05:08:19+0000",
#        "name": "YSNAP - Youth SRHR Network in East and South East Asia and Pacific",
#        "id": "384948908245321"
#       },
#       {
#        "category": "Organization",
#        "created_time": "2013-09-01T15:47:50+0000",
#        "name": "Creative Content Association Malaysia",
#        "id": "392164994176906"
#       },
#       {
#        "category": "University",
#        "created_time": "2013-08-30T12:02:02+0000",
#        "name": "International Medical University - IMU",
#        "category_list": [
#         {
#          "id": "145118935550090",
#          "name": "Medical & Health"
#         },
#         {
#          "id": "108051929285833",
#          "name": "College & University"
#         },
#         {
#          "id": "187751327923426",
#          "name": "Educational Organization"
#         }
#        ],
#        "id": "142485409139475"
#       },
#       {
#        "category": "Company",
#        "created_time": "2013-08-27T14:48:14+0000",
#        "name": "Makespace",
#        "category_list": [
#         {
#          "id": "169026306477520",
#          "name": "Hardware & Tools Service"
#         },
#         {
#          "id": "139823692748565",
#          "name": "Computers & Electronics"
#         }
#        ],
#        "id": "120248358159193"
#       },
#       {
#        "category": "Community",
#        "created_time": "2013-08-27T14:40:29+0000",
#        "name": "#BetterCities",
#        "id": "102330869913968"
#       },
#       {
#        "category": "Community",
#        "created_time": "2013-08-25T12:15:43+0000",
#        "name": "Yolyo",
#        "id": "190519154456709"
#       },
#       {
#        "category": "Small business",
#        "created_time": "2013-08-24T08:22:30+0000",
#        "name": "The Great Startup Wiki",
#        "id": "400937440017777"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2013-06-25T04:29:09+0000",
#        "name": "United Nations Association-USA East Bay",
#        "category_list": [
#         {
#          "id": "2603",
#          "name": "Non-Profit Organization"
#         }
#        ],
#        "id": "418095661575802"
#       }
#      ]
#     }
#    },
#    {
#     "id": "823790712",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTQ0NDQyMzA4NTc4OTQ0NA==",
#        "before": "MjA5MzYxOTg5MjE1"
#       },
#       "next": "https://graph.facebook.com/v1.0/823790712/likes?limit=10&access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD&after=MTQ0NDQyMzA4NTc4OTQ0NA%3D%3D"
#      },
#      "data": [
#       {
#        "category": "Sports event",
#        "created_time": "2014-06-05T09:59:53+0000",
#        "name": "The Olympic Games",
#        "category_list": [
#         {
#          "id": "1805",
#          "name": "Sports Event"
#         }
#        ],
#        "id": "209361989215"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-05-30T03:27:41+0000",
#        "name": "TPNC641",
#        "id": "1413872982227015"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2014-05-20T02:59:10+0000",
#        "name": "Smokey Bear",
#        "id": "20724741109"
#       },
#       {
#        "category": "App page",
#        "created_time": "2014-05-07T09:36:33+0000",
#        "name": "Pixel Dungeon",
#        "id": "440156436054062"
#       },
#       {
#        "category": "Book",
#        "created_time": "2014-05-01T23:49:32+0000",
#        "name": "On the Road",
#        "id": "613324775416871"
#       },
#       {
#        "category": "Education",
#        "created_time": "2014-04-24T01:10:53+0000",
#        "name": "Synesthesia Association at Berkeley",
#        "id": "137841269650523"
#       },
#       {
#        "category": "Business/economy website",
#        "created_time": "2014-04-07T01:28:17+0000",
#        "name": "Money Economics",
#        "id": "384586391588523"
#       },
#       {
#        "category": "Organization",
#        "created_time": "2014-03-11T19:56:25+0000",
#        "name": "Showdown eSports",
#        "id": "1409100372654629"
#       },
#       {
#        "category": "Professional sports team",
#        "created_time": "2014-03-01T07:26:03+0000",
#        "name": "LA Lakers",
#        "id": "144917055340"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-02-26T06:04:14+0000",
#        "name": "Altdevblog",
#        "id": "1444423085789444"
#       }
#      ]
#     }
#    },
#    {
#     "id": "100000968142753"
#    }
#   ]
#  },
#  "id": "10203193585293342",
#  "name": "Christopher Tong"
# }

# %% [markdown]
# Note: If you attempt to run a query for all of your friends' likes and it appears to hang, it is probably because you have a lot of friends who have a lot of likes. If this happens, you may need to add limits and offsets to the fields in the query as described in Facebook's [field expansion](https://developers.facebook.com/docs/reference/api/field_expansion/) documentation. However, the <code>facebook</code> library that we'll use in the next example handles some of these issues, so it's recommended that you hold off and try it out first. This initial example is just to illustrate that Facebook's API is built on top of HTTP.
#
# A couple of field limit/offset examples that illustrate the possibilities follow:
#
# <code>
# fields = 'id,name,friends.limit(10).fields(likes)'            # Get all likes for 10 friends
# fields = 'id,name,friends.offset(10).limit(10).fields(likes)' # Get all likes for 10 more friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# </code>

# %% [markdown]
# ## Example 2. Querying the Graph API with Python

# %%
import facebook # pip install facebook-sdk
import json

# A helper function to pretty-print Python objects as JSON

def pp(o): 
    print json.dumps(o, indent=1)

# Create a connection to the Graph API with your access token

g = facebook.GraphAPI(ACCESS_TOKEN)

# Execute a few sample queries

print '---------------'
print 'Me'
print '---------------'
pp(g.get_object('me'))
print
print '---------------'
print 'My Friends'
print '---------------'
pp(g.get_connections('me', 'friends'))
print
print '---------------'
print 'Social Web'
print '---------------'
pp(g.request("search", {'q' : 'social web', 'type' : 'page'}))
# Out:
# ---------------
# Me
# ---------------
# {
#  "username": "christopher.tong.9",
#  "first_name": "Christopher",
#  "last_name": "Tong",
#  "verified": true,
#  "name": "Christopher Tong",
#  "locale": "en_US",
#  "gender": "male",
#  "updated_time": "2014-04-12T22:31:27+0000",
#  "birthday": "04/27/1991",
#  "link": "https://www.facebook.com/christopher.tong.9",
#  "location": {
#   "id": "113857331958379",
#   "name": "Berkeley, California"
#  },
#  "timezone": 9,
#  "education": [
#   {
#    "school": {
#     "id": "102066276501440",
#     "name": "Arroyo High"
#    },
#    "type": "High School"
#   },
#   {
#    "school": {
#     "id": "112611255417765",
#     "name": "National Taiwan University"
#    },
#    "type": "College"
#   },
#   {
#    "school": {
#     "id": "10111634660",
#     "name": "UC Berkeley"
#    },
#    "type": "College"
#   }
#  ],
#  "id": "10203193585293342"
# }
# ---------------
# My Friends
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/10203193585293342/friends?access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD&limit=5000&offset=5000&__after_id=enc_AezUcDhqqJi1TLX0j3_ucqCJazr_y-J-3wHX3MRsPB2zKHVH70PnAzDDqOYbRKCDDudXnq2AjTaYxOaJvfJfA8k8"
#  },
#  "data": [
#   {
#    "name": "Andrew Chien",
#    "id": "558857930"
#   },
#   {
#    "name": "Steven Wong",
#    "id": "616994476"
#   },
#   {
#    "name": "Brittany Cheng",
#    "id": "618311320"
#   },
#   {
#    "name": "John Li",
#    "id": "637864202"
#   },
#   {
#    "name": "Winston Hsu",
#    "id": "645660973"
#   },
#   {
#    "name": "Jayson Poon",
#    "id": "718469406"
#   },
#   {
#    "name": "Xiaohan Zhang",
#    "id": "823790712"
#   },
#   {
#    "name": "Alex H\u00fc",
#    "id": "100000968142753"
#   }
#  ]
# }
# ---------------
# Social Web
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/search?type=page&q=social+web&access_token=CAACEdEose0cBAOdOUNsdivilewHXw9ZCHKhRi2BZBYm6qdhcfqNeqsKZAWxJpROfZAAMiI5DA3qx2aSCYQGkkMk3YBcQB9xUwwx5L6ADm1wunAYihwuLXlGoxA39PuyWRx0qDOzZBBuWkj8hDOsNEeRx8363I1YpsbH6X56mrmlYWwKDBeyJZC1VAoFo7RTG0ZD&limit=5000&offset=5000&__after_id=enc_AezR59OuiNmUUSMn_wJHsOAP0AAsFauzp07iEJxHrR1jry_xMrcENFe06ABEBLaX8lEskCPL7dWWtUD3v08iJcdR"
#  },
#  "data": [
#   {
#    "category": "Website",
#    "name": "Social Webshop",
#    "id": "1394913830760636"
#   },
#   {
#    "category": "Radio station",
#    "name": "WebRadio Social",
#    "id": "172438649562650"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web.Search.Social",
#    "id": "214631441934914"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social",
#    "id": "481173118576926"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Girl",
#    "id": "1425389227704470"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialWebMarketing",
#    "id": "226633110719998"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social & Web Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "172427156148334"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWeb.ro",
#    "id": "185753574790507"
#   },
#   {
#    "category": "Business services",
#    "name": "socialWEB",
#    "id": "114355558650055"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWebOS",
#    "category_list": [
#     {
#      "id": "2703",
#      "name": "Computers/Internet Website"
#     }
#    ],
#    "id": "358524254168284"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Alliance",
#    "id": "160477007390933"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop UK",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "367809806695037"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Cafe",
#    "id": "255596497809113"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Sherpas",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "105830116116453"
#   },
#   {
#    "category": "Interest",
#    "name": "Social web",
#    "id": "112879218725926"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "441220109348770"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebSocial",
#    "id": "208290102524008"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social Marketing",
#    "id": "161192167329576"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webforce",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "128172607258182"
#   },
#   {
#    "category": "Community",
#    "name": "Social WEB",
#    "id": "295703510589892"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Website",
#    "id": "210604392401626"
#   },
#   {
#    "category": "Local business",
#    "name": "Web Social Marketing Firenze",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "179635912063410"
#   },
#   {
#    "category": "Musician/band",
#    "name": "WebtonSocial",
#    "id": "151651414881841"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "103944626326539"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Day",
#    "id": "137161799695400"
#   },
#   {
#    "category": "Company",
#    "name": "Web Social",
#    "id": "638114226281677"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Promoter",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "657099161012700"
#   },
#   {
#    "category": "App page",
#    "name": "Social Web Reporter",
#    "id": "598817503529463"
#   },
#   {
#    "category": "Professional services",
#    "name": "WebSpot Social",
#    "id": "175322602545416"
#   },
#   {
#    "category": "Book",
#    "name": "Mining the Social Web",
#    "id": "146803958708175"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Whitedrop  Web Marketing Social",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "681921881866837"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Associates",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "327997047315600"
#   },
#   {
#    "category": "Local business",
#    "name": "Web1 Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "119307778101744"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media Siti Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "553637281423867"
#   },
#   {
#    "category": "App page",
#    "name": "SocialWebbie",
#    "id": "217112891701827"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Webmarks",
#    "id": "230470560302996"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Nerd",
#    "id": "121955387828900"
#   },
#   {
#    "category": "Community",
#    "name": "WebdDee Social Community",
#    "id": "134952703245683"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Factory",
#    "id": "67783847861"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "502604446522710"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "SOCIAL WEBSITE",
#    "id": "290608457641244"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Genesis Web Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "186129094876663"
#   },
#   {
#    "category": "Community",
#    "name": "Social Website",
#    "id": "1413569742260889"
#   },
#   {
#    "category": "Website",
#    "name": "Social Website",
#    "id": "1481377618765430"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Websurf Social Media",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "102106206533278"
#   },
#   {
#    "category": "Teens/kids website",
#    "name": "Web Social",
#    "id": "439935936081318"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "669751383086793"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Strategies",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "8387137434"
#   },
#   {
#    "category": "Education",
#    "name": "WebSocial",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "192541364117143"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop Italy",
#    "id": "610458242362481"
#   },
#   {
#    "category": "Company",
#    "name": "Weber Shandwick Social Impact",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "89444069963"
#   },
#   {
#    "category": "Concert venue",
#    "name": "SocialWeb",
#    "id": "186493478082456"
#   },
#   {
#    "category": "Local business",
#    "name": "WebSocialTraffic",
#    "id": "19939664284"
#   },
#   {
#    "category": "App page",
#    "name": "Web Social Mania",
#    "id": "445746788774576"
#   },
#   {
#    "category": "Software",
#    "name": "Web and social media traffic bundles",
#    "id": "659364417455948"
#   },
#   {
#    "category": "Education website",
#    "name": "Social Web Learning",
#    "id": "149583259175"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Web Tactics",
#    "category_list": [
#     {
#      "id": "2237",
#      "name": "Small Business"
#     }
#    ],
#    "id": "162973743866087"
#   },
#   {
#    "category": "Education",
#    "name": "Social Web Academy",
#    "id": "192046090848741"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Tools",
#    "id": "403059893050740"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Impact Web",
#    "id": "196321800413834"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     },
#     {
#      "id": "192021210817573",
#      "name": "Public Relations"
#     },
#     {
#      "id": "192119584190796",
#      "name": "Event"
#     }
#    ],
#    "id": "144307838980365"
#   },
#   {
#    "category": "School",
#    "name": "Social web - \u05e1\u05d5\u05e9\u05d9\u05d0\u05dc \u05d5\u05d5\u05d1",
#    "id": "419507011456285"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Innovation",
#    "id": "162028037196792"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Web Talks",
#    "id": "316613681700247"
#   },
#   {
#    "category": "Education",
#    "name": "ITE College West - Nitec in Social Media and Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "162257397196866"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web Thing",
#    "id": "114874051893438"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "145218172174013"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "156184496617"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Ranking",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "470852336273104"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webs",
#    "id": "174735529355893"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "My Social Web",
#    "category_list": [
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     }
#    ],
#    "id": "76277666156"
#   },
#   {
#    "category": "Local business",
#    "name": "Codesky Web Design & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "278298328945358"
#   },
#   {
#    "category": "Community organization",
#    "name": "Social Web Tech Talk",
#    "id": "173272359544586"
#   },
#   {
#    "category": "Local business",
#    "name": "Allographics",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "181729338411"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social Dev",
#    "id": "233682666821223"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Leads",
#    "id": "118076131540902"
#   },
#   {
#    "category": "Company",
#    "name": "Enova4U Dise\u00f1o Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "218721764817225"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social WEB",
#    "id": "644404665577920"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Promotions",
#    "id": "234335963269949"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web in Fermento - Marketing nel Social Web e NewMedia Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "125310277520246"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Dzine",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "122698737762622"
#   },
#   {
#    "category": "Entrepreneur",
#    "name": "SocialBo",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "475997555787520"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Votigo Social Media Solutions",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "30234388700"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Act",
#    "id": "583432211721362"
#   },
#   {
#    "category": "Company",
#    "name": "SocialWeb Consulting",
#    "id": "177391935634180"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webology",
#    "id": "199369666770042"
#   },
#   {
#    "category": "Community",
#    "name": "Web Social",
#    "id": "231682236924947"
#   },
#   {
#    "category": "Community",
#    "name": "Social Webs",
#    "id": "159735864118250"
#   },
#   {
#    "category": "App page",
#    "name": "SocialWebshop",
#    "id": "509989109127083"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webius",
#    "category_list": [
#     {
#      "id": "177721448951559",
#      "name": "Workplace & Office"
#     }
#    ],
#    "id": "353444191416919"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social / Web Marketing Agency - Stir USA | Canada",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "152246029758"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "118119234870548"
#   },
#   {
#    "category": "News/media website",
#    "name": "The Social Web Analyst",
#    "id": "117650487601"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web Traffic & Social Networking",
#    "id": "159898507447542"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Web Media",
#    "id": "198866480158068"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Social Web Games",
#    "id": "303818923034509"
#   },
#   {
#    "category": "Community organization",
#    "name": "WebMissing -Official Page&Social",
#    "category_list": [
#     {
#      "id": "436846369665656",
#      "name": "Public Utility"
#     }
#    ],
#    "id": "910350912312116"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Manager Web",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "339197272789256"
#   },
#   {
#    "category": "Company",
#    "name": "Webshoutz be social",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "502559819771053"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Grafdom - Web Design & Social Media",
#    "id": "190124415513"
#   },
#   {
#    "category": "Company",
#    "name": "Social web consulting",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ],
#    "id": "438991686226624"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web - UC3M",
#    "id": "641372659269815"
#   },
#   {
#    "category": "Company",
#    "name": "Social Semantic Web",
#    "id": "36575011414"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webfluence Social Media & Internet Marketing",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "112879788755706"
#   },
#   {
#    "category": "Personal website",
#    "name": "THE JAGUAR SOCIAL NETWORK  WEBSITE",
#    "id": "114852928532072"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Ecosystem",
#    "id": "186923664693877"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Jenna McWatters - Web Design and Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "1416729695251458"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web CT",
#    "id": "133897929978754"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebSocial Business Solutions",
#    "id": "444124702299250"
#   },
#   {
#    "category": "Website",
#    "name": "Web | SEO | Social",
#    "id": "107829512591899"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social-Work Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "243859642426303"
#   },
#   {
#    "category": "Software",
#    "name": "Web design and social media specialists",
#    "id": "553498398099834"
#   },
#   {
#    "category": "Artist",
#    "name": "Ion Gonzaga, The Social Web Designer",
#    "id": "120679007979099"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Wizard",
#    "id": "169089429771025"
#   },
#   {
#    "category": "Interest",
#    "name": "Web social",
#    "id": "726519714039235"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "In Social Web",
#    "id": "168072826666497"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Cloud",
#    "id": "361274951376"
#   },
#   {
#    "category": "Local business",
#    "name": "Social web design by x10industries",
#    "id": "330043283780"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Week Connecticut",
#    "id": "128455980522180"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "iSocialWeb",
#    "id": "462294513847158"
#   },
#   {
#    "category": "Interest",
#    "name": "Social website",
#    "id": "198566960212311"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Dreams: Web Series",
#    "id": "612698088813986"
#   },
#   {
#    "category": "Local business",
#    "name": "etrade.ba | Social Media & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "217376194979375"
#   },
#   {
#    "category": "Education",
#    "name": "Social Media & Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "120366748050821"
#   },
#   {
#    "category": "Community",
#    "name": "Webster Alumni Social Group",
#    "id": "487171701376262"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Web Cafe TV",
#    "id": "149184731910179"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Design",
#    "id": "281249708648873"
#   },
#   {
#    "category": "Telecommunication",
#    "name": "Entire Web - Social Network",
#    "id": "280834978742184"
#   },
#   {
#    "category": "Website",
#    "name": "WebSocial.ly",
#    "id": "113759552036905"
#   },
#   {
#    "category": "Personal website",
#    "name": "Social Web Monitoring",
#    "id": "111019338966579"
#   },
#   {
#    "category": "Community organization",
#    "name": "SocialWebConneXion.com",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "152880021441864",
#      "name": "Community Organization"
#     }
#    ],
#    "id": "636570933034875"
#   },
#   {
#    "category": "Website",
#    "name": "Web Social Tourism",
#    "id": "301608313292038"
#   },
#   {
#    "category": "Product/service",
#    "name": "On The Webb Social Media Services",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "210125749066257"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "275989642418291"
#   },
#   {
#    "category": "Home improvement",
#    "name": "Websites & Social Media",
#    "category_list": [
#     {
#      "id": "108427109235243",
#      "name": "Home Improvement"
#     }
#    ],
#    "id": "213642188759243"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Bee Web Marketing and Design",
#    "id": "187494864706626"
#   },
#   {
#    "category": "Website",
#    "name": "SocialWebLike",
#    "id": "101946616632016"
#   },
#   {
#    "category": "Website",
#    "name": "WebCamSocial.com",
#    "id": "193570570659564"
#   },
#   {
#    "category": "News/media website",
#    "name": "Advertising on the Web",
#    "id": "28705232393"
#   },
#   {
#    "category": "Retail and consumer merchandise",
#    "name": "Social Web Deals",
#    "id": "225923010951805"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media & Websites",
#    "id": "278572212299892"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media Web Development",
#    "id": "125248858533"
#   },
#   {
#    "category": "Business services",
#    "name": "Boxless Media - Social Media & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "150063728530867"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "SocialWebCoding",
#    "id": "155266187877368"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Gym",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "185900881450649",
#      "name": "Personal Coaching"
#     }
#    ],
#    "id": "488323237847526"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Web Social Palmares",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "267515243361878"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Life Social Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "147895125402338"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Website",
#    "id": "1409211522669854"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Media Webster",
#    "id": "416689008392125"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media Web Solutions",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "182527338476147"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "The Social Media Web Genie",
#    "id": "537321239622767"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Real Estate",
#    "id": "164269200441810"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Media Webinars",
#    "id": "191804081004433"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social webs cheats",
#    "id": "227273367442760"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social Business",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "620197398021531"
#   },
#   {
#    "category": "Community",
#    "name": "Webchat.my IRC Social Network",
#    "id": "398080426963854"
#   },
#   {
#    "category": "Internet/software",
#    "name": "ICTIP - Online Marketing, Social Media Management and Web Development",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "147188657823"
#   },
#   {
#    "category": "Company",
#    "name": "Web Infotech Solutions",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "400241243372561"
#   },
#   {
#    "category": "App page",
#    "name": "Defensio Social Web Security",
#    "id": "243130985760964"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialWebRx",
#    "id": "203998269733762"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web Buzzr Social Media",
#    "id": "207341495979989"
#   },
#   {
#    "category": "Professional services",
#    "name": "Visibly Connected - Web Design, Social Media Manager, & SEO",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "190805541029564"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web&Social Life - Italy",
#    "id": "162181413905627"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Sunset Social & Web",
#    "id": "520445137969225"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Cosmosale Web Traffic & Social Marketing",
#    "id": "304240259630793"
#   },
#   {
#    "category": "Interest",
#    "name": "Webcam Social Shopper",
#    "id": "408492742542624"
#   },
#   {
#    "category": "Website",
#    "name": "Web Design Social Apps",
#    "id": "239709786137413"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Semantic Web",
#    "id": "103989939638996"
#   },
#   {
#    "category": "Business services",
#    "name": "Web Social Media Marketing",
#    "id": "405802852763407"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Communication",
#    "category_list": [
#     {
#      "id": "132008380200065",
#      "name": "Image Consultant"
#     }
#    ],
#    "id": "165807746962152"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "\u062a\u0639\u0644\u0645 \u0627\u0644\u0634\u0628\u0643\u0627\u062a \u0627\u0644\u0627\u062c\u062a\u0645\u0627\u0639\u064a\u0647",
#    "id": "117728265015590"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web BREAKFAST",
#    "id": "175318852545291"
#   },
#   {
#    "category": "Local business",
#    "name": "Web Savvy Social Media",
#    "id": "132456623459954"
#   },
#   {
#    "category": "Website",
#    "name": "Webverts Social Coupons",
#    "id": "290755324388883"
#   },
#   {
#    "category": "Work position",
#    "name": "Web e Social Marketing",
#    "id": "658922750846405"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Social-Webcam",
#    "id": "138187269563360"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Media Websites",
#    "id": "121361064703333"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Web Academy",
#    "id": "133517650020227"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web",
#    "id": "456664834354636"
#   },
#   {
#    "category": "Website",
#    "name": "SocialProofWeb",
#    "id": "475543625793316"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Pelican Web Services",
#    "id": "446747078697655"
#   },
#   {
#    "category": "Business services",
#    "name": "Web Social Marketing",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "162081643861223"
#   },
#   {
#    "category": "Business services",
#    "name": "Website Social Media Development",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "522531034450480"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web/Social Marketing",
#    "id": "172670552803004"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Tips",
#    "id": "146398262047288"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Caroline Webb   Digital & Social Media",
#    "id": "219957014881658"
#   },
#   {
#    "category": "Website",
#    "name": "Social Media Webinar",
#    "id": "119970001420128"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Real-time Social Web",
#    "id": "121363354543881"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Rory Martin Seattle Web Design and Social Media",
#    "id": "198472820260168"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Qweboo \"Control Your Social Web\"",
#    "id": "146142715411167"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webdesign",
#    "id": "220350687983200"
#   },
#   {
#    "category": "Company",
#    "name": "Social Webfashion",
#    "id": "476630749055988"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Q and A",
#    "id": "433133770070530"
#   },
#   {
#    "category": "Retail and consumer merchandise",
#    "name": "Social Network Webshop",
#    "id": "424002204310411"
#   },
#   {
#    "category": "Public figure",
#    "name": "Web Success Diva Social Internet Marketing",
#    "id": "51426770632"
#   },
#   {
#    "category": "Small business",
#    "name": "Web Angels | SEO & Social Media",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     }
#    ],
#    "id": "225436744190231"
#   },
#   {
#    "category": "Education",
#    "name": "Master in Non-Conventional Marketing +Social Media",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "179550135412710"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Instus - Social Media & Web Based Services",
#    "id": "462458733874919"
#   },
#   {
#    "category": "Website",
#    "name": "My Social Media Website",
#    "id": "265276823522152"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Buzz Websites",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "195634827182774"
#   },
#   {
#    "category": "Local business",
#    "name": "Dot Ingenuity Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "131570646875176"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SEO Workers - Forensic SEO & Social Semantic Web Consulting",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "22362057425"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Marketing/Web expert",
#    "id": "363931623705636"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Web Wide Social Media Dissemination",
#    "id": "1491913881040227"
#   },
#   {
#    "category": "Website",
#    "name": "Web and Social Media Designer Portfolio",
#    "id": "633515570032384"
#   },
#   {
#    "category": "Local business",
#    "name": "Biz Social Webdesign / Web Design by Jenn",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "115395771827453"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialEnterpriseWebsites.com",
#    "id": "208744325821683"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "webfeuer - Social Media und mehr!",
#    "id": "369613539636"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Douro at Social Media Networking",
#    "id": "454451468008331"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Life - The Web Show",
#    "id": "190526720994424"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SeashoreWeb Social Media Marketing",
#    "id": "106838049410541"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media On The Web",
#    "id": "155217227871015"
#   },
#   {
#    "category": "Local business",
#    "name": "Quisk Design - Websites, Branding & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "328671177050"
#   },
#   {
#    "category": "Local business",
#    "name": "~ SocialFly ~ Dise\u00f1o Web 2.0",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "317064404977552"
#   },
#   {
#    "category": "Product/service",
#    "name": "Web & Social Media Strategy",
#    "id": "219292161416145"
#   },
#   {
#    "category": "Company",
#    "name": "YouLikeFans - Social Media Website Tool & Community",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "436356429737029"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialMedia Designs",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "173876899342866"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Adapting Social Web Design & Digital Marketing",
#    "id": "232898900191494"
#   },
#   {
#    "category": "Professional services",
#    "name": "Local Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "292125494205150"
#   },
#   {
#    "category": "Small business",
#    "name": "Ignite Social Web",
#    "id": "124131750957589"
#   },
#   {
#    "category": "Website",
#    "name": "Islamic & Social Website - abswerbd.com",
#    "id": "677061112307489"
#   },
#   {
#    "category": "Business services",
#    "name": "London Web design, SEO, Social Media. London Dynamics Web Design Agency",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "253027144832586"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webstore",
#    "id": "236710696370261"
#   },
#   {
#    "category": "Community organization",
#    "name": "Go Long Island - The Social Website for Long Island",
#    "id": "118029078273421"
#   },
#   {
#    "category": "Professional services",
#    "name": "Impulsive Labs Web Design & Social Media Management",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "261688960613759"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Web Brasil",
#    "id": "363231467061867"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Ri Web - Web Design, SEO and Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "112787802074827"
#   },
#   {
#    "category": "Professional services",
#    "name": "Computer Web Social Media of Shelby",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "207112126105577"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Blog",
#    "id": "120064018007609"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Meta Social Web",
#    "id": "117185225027930"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web2social",
#    "id": "127415450642739"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web & Social Media Pundit: Consultancy & Management Services",
#    "id": "107316135994400"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Anxiety - A Web Series",
#    "id": "107080656067158"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebMedium Social Media Marketing",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "1390339774520138"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Website Wellness - Web, SEO & Social Marketing",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "173869832661277"
#   },
#   {
#    "category": "Science website",
#    "name": "Social Web Disigner of bangladesh",
#    "id": "377151669061858"
#   },
#   {
#    "category": "Internet/software",
#    "name": "WebKit - Social Networks, E-commerce, Web Development",
#    "id": "96394316810"
#   },
#   {
#    "category": "Community",
#    "name": "Web Trends & Social Media",
#    "id": "352574378177313"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Leading Logic - Web, Social, Marketing, Design",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "136481676384923"
#   },
#   {
#    "category": "Internet/software",
#    "name": "NetSocialWeb",
#    "id": "434562719914740"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop FR",
#    "id": "235406569990322"
#   },
#   {
#    "category": "Non-profit organization",
#    "name": "VFW 898 Col. J.B. Weber Post",
#    "category_list": [
#     {
#      "id": "2603",
#      "name": "Non-Profit Organization"
#     }
#    ],
#    "id": "277223265698189"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialBase",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "351653524868037"
#   },
#   {
#    "category": "Club",
#    "name": "web radio Cidade Gospel",
#    "category_list": [
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     }
#    ],
#    "id": "221630171295138"
#   },
#   {
#    "category": "Local business",
#    "name": "Webster Hall Club",
#    "category_list": [
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     }
#    ],
#    "id": "211396812321665"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media 180 | A Complete Turn in Business Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     }
#    ],
#    "id": "130180033702195"
#   },
#   {
#    "category": "Local business",
#    "name": "My Social Marketing Network",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "145718952145119"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Veranet SocialMedia",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "312929368858881"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Media Montana",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "201528873201605",
#      "name": "Management Service"
#     }
#    ],
#    "id": "776566225694355"
#   },
#   {
#    "category": "Business services",
#    "name": "3YESWEB.com Mobile Local Social Website Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "580740251986719"
#   },
#   {
#    "category": "Company",
#    "name": "Social Media Ninjas | Santa Rosa Internet Marketing Consultants",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "152123711502236"
#   },
#   {
#    "category": "Company",
#    "name": "More Cabbage Social PR, Branding, & Websites",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     }
#    ],
#    "id": "216734806323"
#   },
#   {
#    "category": "Company",
#    "name": "Cybernetic Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "184672711611439"
#   },
#   {
#    "category": "Club",
#    "name": "Boys & Girls Club of Weber Davis- Roy",
#    "category_list": [
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     },
#     {
#      "id": "181811248521973",
#      "name": "Child Care"
#     },
#     {
#      "id": "191373470890862",
#      "name": "School Transportation"
#     }
#    ],
#    "id": "386016781524642"
#   },
#   {
#    "category": "Local business",
#    "name": "Cerebral Palsy of Tri-County Webb City Development Center",
#    "category_list": [
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     }
#    ],
#    "id": "127187537303305"
#   },
#   {
#    "category": "Internet/software",
#    "name": "7Blaze - True Social Experience",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "215297361818239"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "276851379109837"
#   },
#   {
#    "category": "Business services",
#    "name": "Valley Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "484040034958854"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Driver",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "173652409354108"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Impact Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "192385760849206"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "The Mobi  Fanpage Guy",
#    "id": "303157799810614"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web TV. We socialize your passion",
#    "id": "285679378241848"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Katink web design & social media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "400114793423652"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "309046269117622"
#   },
#   {
#    "category": "Professional services",
#    "name": "RedHot Design | Web Designers + Social Media Strategists",
# ...
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Networking, Web, Privacy & Security",
#    "id": "117452538334568"
#   },
#   {
#    "category": "Product/service",
#    "name": "Designs by Desiree Business Solutions",
#    "id": "436943043033766"
#   },
#   {
#    "category": "Local business",
#    "name": "MX - web & social marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "121637227912375"
#   },
#   {
#    "category": "Product/service",
#    "name": "Web Presence, Website, Social Networking, Trailers l Sweet Communication",
#    "id": "163374786487"
#   },
#   {
#    "category": "Tv channel",
#    "name": "WEB TV Social Network - GR Comunicazione",
#    "id": "581952661860081"
#   },
#   {
#    "category": "Professional services",
#    "name": "5th Gear Web Photo Social",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "181475575221097",
#      "name": "Photographer"
#     }
#    ],
#    "id": "135480773315970"
#   },
#   {
#    "category": "Internet/software",
#    "name": "FUA Social Web",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "1410567895848855"
#   },
#   {
#    "category": "Product/service",
#    "name": "RCMS - Web\u30b5\u30a4\u30c8\u69cb\u7bc9\u30d7\u30e9\u30c3\u30c8\u30d5\u30a9\u30fc\u30e0",
#    "id": "119731478054606"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Webinars and Seminars",
#    "id": "640189532715173"
#   },
#   {
#    "category": "Business services",
#    "name": "Justin Mulder - Web Design & Social Media Consultant",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ],
#    "id": "273795329402044"
#   },
#   {
#    "category": "Legal/law",
#    "name": "SWA Social Web Avvvocati & Webnews Giuridiche",
#    "id": "472013526210740"
#   },
#   {
#    "category": "Website",
#    "name": "vGal Website Content Writing, Social Media & Solutions",
#    "id": "120224928014658"
#   },
#   {
#    "category": "Community",
#    "name": "Website design and social mdeia promotion ludhiana punjab india",
#    "id": "732530496770460"
#   },
#   {
#    "category": "Software",
#    "name": "Catharsis Social Web Widgets",
#    "id": "286407764855900"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Deutschland",
#    "id": "448618018530618"
#   },
#   {
#    "category": "Company",
#    "name": "Digital Domain - Website & Social Media Specialists",
#    "id": "357741767651125"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Likefollower.it - Social & Web Marketing",
#    "id": "493833740703153"
#   },
#   {
#    "category": "Local business",
#    "name": "Web-Graphic Designer / Social Media",
#    "id": "389293934485009"
#   },
#   {
#    "category": "University",
#    "name": "Master Universitario in \"Web communication & social media\"",
#    "category_list": [
#     {
#      "id": "108051929285833",
#      "name": "College & University"
#     }
#    ],
#    "id": "291350937559881"
#   },
#   {
#    "category": "Just for fun",
#    "name": "Megalast.webs.com Social",
#    "id": "264097790271896"
#   },
#   {
#    "category": "Internet/software",
#    "name": "TiWebDesign",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "340506199316371"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Socialfan.it Viral_Social_Media_Web",
#    "id": "597225060374864"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media and Website Buzz - Tips and Virtual Assistants",
#    "id": "130510156972556"
#   },
#   {
#    "category": "Small business",
#    "name": "Paradigm Panda - Web Design, Social Media, SEO and Integrated Marketing",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ],
#    "id": "600852386654218"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Ojaswi Web",
#    "id": "329902693763635"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Super Socialites| Web Design-Social Media & Marketing",
#    "id": "128655320529070"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Memeworx: Web design  Search Engine Optimisation   Social Media Marketing",
#    "category_list": [
#     {
#      "id": "2255",
#      "name": "Computers/Technology"
#     }
#    ],
#    "id": "59582672006"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Southern Cross Web and Social Marketing",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "448918335184289"
#   },
#   {
#    "category": "Education",
#    "name": "Master in Social Media e Web Community Manager",
#    "category_list": [
#     {
#      "id": "186998168001766",
#      "name": "Private School"
#     }
#    ],
#    "id": "298574890156815"
#   },
#   {
#    "category": "Community",
#    "name": "Marci Rosenblum - Expert SEO Specialist, Web Traffic, Social Media Marketer",
#    "id": "70863093045"
#   },
#   {
#    "category": "Professional services",
#    "name": "ProShay Web Development | St George Utah Social Media Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "300599270362"
#   },
#   {
#    "category": "Local business",
#    "name": "Ewing Enterprise - Custom Website Packages, SEO Services,  Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "131829320161316"
#   },
#   {
#    "category": "Internet/software",
#    "name": "APclick - social media marketing e web writing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "171645079640594"
#   },
#   {
#    "category": "Professional services",
#    "name": "Shelby McCoy: Social Media & Website Management",
#    "id": "162378827188346"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Digital For Dummies | Social, Web & other Technical Stuff",
#    "id": "476313985731653"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Check-in Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "480712315274434"
#   },
#   {
#    "category": "Software",
#    "name": "Socialspy Social Website Marketing Software",
#    "id": "468155203305128"
#   },
#   {
#    "category": "Company",
#    "name": "WebsiteDeals.NL Categorie: Social Media",
#    "id": "193147644154657"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Foxtech Social Media Marketing & Website Development",
#    "id": "767421946607847"
#   },
#   {
#    "category": "Company",
#    "name": "Wesome Web & Social Media solutions",
#    "id": "540823335945236"
#   },
#   {
#    "category": "Internet/software",
#    "name": "MURCON - Websites and Search, Email, and Social Media Marketing, Databases",
#    "id": "108029989217335"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Kreativevue Web Design & Social Media",
#    "id": "426710170752907"
#   },
#   {
#    "category": "Small business",
#    "name": "Susannah Pryal Web + Social Media Design + Development",
#    "id": "109753029109669"
#   },
#   {
#    "category": "Professional services",
#    "name": "Zipolita'z Web Dezign & Social Mediaz",
#    "id": "434668943255825"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Advertising Enterprises (Web Design, Social Media, SEO &  Marketing)",
#    "id": "6049597557"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Gulf Coast Social Media & Web Design",
#    "id": "280769368741562"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Chicks Design, Social Media & SEO tips and info",
#    "id": "223470797691762"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Best Website To Buy Social media followers",
#    "id": "624740417603694"
#   },
#   {
#    "category": "Product/service",
#    "name": "Pete G's Webmaster & Social Media Services",
#    "id": "819148984766568"
#   },
#   {
#    "category": "Local business",
#    "name": "Web2Lab Studio - Web Social Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "242654909089118"
#   },
#   {
#    "category": "Product/service",
#    "name": "ClickNSmart - Social Web Conference & Group Chat",
#    "id": "173964552642475"
#   },
#   {
#    "category": "Personal website",
#    "name": "My Friends Book ~ Social Networking Website",
#    "id": "249459055096850"
#   },
#   {
#    "category": "Professional services",
#    "name": "Web Marketing & Social Media Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "628817540514835"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Mobile Experts / Mobile Website Design",
#    "id": "132580123421686"
#   },
#   {
#    "category": "Company",
#    "name": "Fuzzbox Designs Limited - Web, Graphics, Social Media",
#    "id": "348306219052"
#   },
#   {
#    "category": "Organization",
#    "name": "SowSkills - Social-Web-Skills for eldery people",
#    "id": "225477664142196"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Malekoo Web Development and Social Media Marketing",
#    "id": "449187528446529"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "\"Get Social\" Media & Web Design",
#    "id": "205417559593175"
#   },
#   {
#    "category": "Education",
#    "name": "The Social Mobile Web Business Conference Glasgow",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "161216853943193"
#   },
#   {
#    "category": "Website",
#    "name": "SocialMaster",
#    "id": "202722683097793"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Studio316 - Web, Graphic & Social Media",
#    "id": "140864749342125"
#   },
#   {
#    "category": "Internet/software",
#    "name": "iPad Tablet Web, Games, eBoook, Social Networking Application Development",
#    "id": "113316392018190"
#   },
#   {
#    "category": "Sports venue",
#    "name": "Golf - Social Websites",
#    "id": "581432215309094"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web Marketing e Social Network",
#    "id": "124569380964031"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Siti Web Social Marketing claudio corti",
#    "id": "143481949191843"
#   },
#   {
#    "category": "Website",
#    "name": "WebTouchMedia - Online Business SEO and Social Media Marketing Simplified",
#    "id": "115979038426255"
#   },
#   {
#    "category": "Personal website",
#    "name": "V Crown Social website",
#    "id": "509251595812044"
#   },
#   {
#    "category": "Business services",
#    "name": "PresentationMultimedia - Social Media, SEO, DVD & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "173932019310961"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Bonobo - Web & Social Media",
#    "id": "185366164983180"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SEOSubmitters.com SEO Web Based Internet Marketing & Social Media Marketing",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     }
#    ],
#    "id": "150468278358053"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Net Club Emission 100% WEB 100 %LYON",
#    "id": "230243223809910"
#   },
#   {
#    "category": "Organization",
#    "name": "NYSC  OYO Social Web",
#    "id": "1439946206246362"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Quan Web Design & Development",
#    "id": "118839434841221"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "Kelowna Website Design | Social Media | SEO | - WebSpin Media -",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "127548610727481"
#   },
#   {
#    "category": "Local business",
#    "name": "Indie43 - Web Design, Social Media, Branding",
#    "id": "114867158566659"
#   },
#   {
#    "category": "Professional services",
#    "name": "Elliottsweb - Website Design, SEO and Social Media Marketing",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "324412657671756"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Caffeine Clicks: Website Design, SEO & Social Media - Miami, FL",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "238499129597990"
#   },
#   {
#    "category": "App page",
#    "name": "Web Master Social Media",
#    "id": "195512703929741"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Elite Ideas - Websites, Marketing, Social Media",
#    "id": "120959061268900"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Mais4 Social Web",
#    "id": "201920803163928"
#   },
#   {
#    "category": "Health/beauty",
#    "name": "Vegans  Website Designs and Social Media Solutions",
#    "id": "156020154458298"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Farrus Web Dev & Social Media Services",
#    "id": "840916265934140"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "White Social Web",
#    "id": "593079957405930"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Marketing - Your Website Inside FB",
#    "id": "467525046604604"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Fresh - Social media, web & adv",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "524185097668322"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Complete Dreams Design - Web, Social, Graphic, and Video Design",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "119846254710406"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Elliottsweb | Miami Website Design | SEO | Social Media Experts",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "222342297805673"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Corso di Web e Social Marketing",
#    "category_list": [
#     {
#      "id": "162237190493977",
#      "name": "Computer Training"
#     }
#    ],
#    "id": "209017115940429"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Multicity Producciones - Web & Social Media Manager",
#    "category_list": [
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "374507915983701"
#   }
#  ]
# }

# %% [markdown]
# ## Example 3. Results for a Graph API query for Mining the Social Web

# %%
# Get an instance of Mining the Social Web
# Using the page name also works if you know it.
# e.g. 'MiningTheSocialWeb' or 'CrossFit'
mtsw_id = '146803958708175'
pp(g.get_object(mtsw_id))
# Out:
# {
#  "website": "http://miningthesocialweb.com",
#  "can_post": true,
#  "company_overview": "Like It here on Facebook!\n\nFollow @SocialWebMining on Twitter: http://twitter.com/SocialWebMining\n\nGet the source code for the revised and expanded second edition on GitHub: http://bit.ly/MiningTheSocialWeb2E\n\nGet the (now legacy) source code for the first edition on GitHub: http://bit.ly/SocialWebMining",
#  "mission": "Teaches you how to navigate the most popular social web APIs to access, collect, analyze, and visualize social web data with IPython Notebook and other easy to use Python packages and visualization tools.",
#  "founded": "January 2011",
#  "likes": 1655,
#  "parking": {
#   "street": 0,
#   "lot": 0,
#   "valet": 0
#  },
#  "general_info": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites - Get it at http://bit.ly/135dHfs",
#  "id": "146803958708175",
#  "category": "Book",
#  "has_added_app": false,
#  "talking_about_count": 25,
#  "is_community_page": false,
#  "username": "MiningTheSocialWeb",
#  "description": "Facebook, Twitter, LinkedIn, Google+, and other social web properties generate a wealth of valuable social data, but how can you tap into this data and discover who\u2019s connecting with whom, which insights are lurking just beneath the surface, and what people are talking about? This book shows you how to answer these questions and many more. Each chapter combines popular and useful social web data with analysis techniques and visualization to help you find the needles in the social haystack that you've been looking for\u2014as well as many you probably didn't even know existed.\n\nIn this expanded and thoroughly revised second edition you\u2019ll learn how to:\n\n* Navigate the most popular social web APIs to access, collect, analyze, and visualize social web data\n* Employ IPython Notebook and other easy to use Python packages such as the Natural Language Toolkit, NetworkX, and Matplotlib to efficiently sift through social web data as part of an experimentally-driven approach to discovering insights in social web data\n* Apply advanced text-mining techniques such as TF-IDF, cosine similarity, collocation analysis, document summarization, and clique detection to human language data that you'll encounter all over the web\n* Bootstrap interest graphs by discovering latent affinities between people, programming languages, and coding projects from GitHub data\n* Visualize social web data with D3, a state-of-the-art HTML5 and JavaScript toolkit\n\nThe book's source code is maintained in a GitHub repository maintained by the author and can be deployed as turn-key virtual machine with each chapter's source code presented in an interactive and easy to use IPython Notebook format. No complex third-party installations or advanced Python knowledge is required to get the most out of this book.",
#  "awards": "Jolt Productivity Award (1st Ed.) -  http://drdobbs.com/joltawards/231500080?pgno=6",
#  "genre": "Data Mining",
#  "checkins": 0,
#  "about": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites. Twitter: @SocialWebMining",
#  "name": "Mining the Social Web",
#  "release_date": "January 2011",
#  "cover": {
#   "source": "https://fbcdn-sphotos-a-a.akamaihd.net/hphotos-ak-frc3/t31.0-8/p180x540/1073953_522831997772034_741301400_o.jpg",
#   "cover_id": 522831997772034,
#   "offset_x": 0,
#   "offset_y": 56
#  },
#  "were_here_count": 0,
#  "link": "https://www.facebook.com/MiningTheSocialWeb",
#  "is_published": true
# }

# %% [markdown]
# ## Example 4. Querying the Graph API for Open Graph objects by their URLs

# %%
# MTSW catalog link
pp(g.get_object('http://shop.oreilly.com/product/0636920030195.do'))

# PCI catalog link
pp(g.get_object('http://shop.oreilly.com/product/9780596529321.do'))
# Out:
# {
#  "id": "http://shop.oreilly.com/product/0636920030195.do",
#  "shares": 228
# }
# {
#  "category": "Book",
#  "about": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "talking_about_count": 0,
#  "description": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "has_added_app": false,
#  "can_post": true,
#  "name": "Programming Collective Intelligence",
#  "link": "http://shop.oreilly.com/product/9780596529321.do",
#  "likes": 18,
#  "parking": {
#   "street": 0,
#   "lot": 0,
#   "valet": 0
#  },
#  "is_community_page": false,
#  "were_here_count": 0,
#  "checkins": 0,
#  "id": "221689464577245",
#  "is_published": true
# }

# %% [markdown]
# ## Example 5. Comparing likes between Coke and Pepsi fan pages

# %%
# Find Pepsi and Coke in search results

pp(g.request('search', {'q' : 'pepsi', 'type' : 'page', 'limit' : 5}))
pp(g.request('search', {'q' : 'coke', 'type' : 'page', 'limit' : 5}))

# Use the ids to query for likes

pepsi_id = '56381779049' # Could also use 'PepsiUS'
coke_id = '40796308305'  # Could also use 'CocaCola'

# A quick way to format integers with commas every 3 digits
def int_format(n): return "{:,}".format(n)

print "Pepsi likes:", int_format(g.get_object(pepsi_id)['likes'])
print "Coke likes:", int_format(g.get_object(coke_id)['likes'])
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/search?limit=5&type=page&q=pepsi&access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&offset=5&__after_id=enc_AeyXLpUeZ3jU1KR-Y0wbxu_3V2dCY1LfHLPU8fVo2_kgzXPzH7nVOTiMaXLT7kwbEYA"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi",
#    "id": "339150749455906"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsithai",
#    "id": "63619711274"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "PepsiCo",
#    "category_list": [
#     {
#      "id": "2252",
#      "name": "Food/Beverages"
#     }
#    ],
#    "id": "260431051694"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi Max",
#    "id": "10098929349"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi Pakistan",
#    "id": "319859607495"
#   }
#  ]
# }
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/search?limit=5&type=page&q=coke&access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&offset=5&__after_id=enc_AezWJjZOC9lJGwboQ4tskt76vmkiLLip4HKCs8KrTqWGiB-hj0LFD3lAT5x1UO_2ypDCvbVJePE-TvBlk90zUceZ"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola",
#    "id": "40796308305"
#   },
#   {
#    "category": "Tv show",
#    "name": "Coke Studio",
#    "category_list": [
#     {
#      "id": "133436743388217",
#      "name": "Arts & Entertainment"
#     }
#    ],
#    "id": "16944632531"
#   },
#   {
#    "category": "Tv show",
#    "name": "Coke Studio at MTV",
#    "id": "127266094017030"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola Zero",
#    "id": "61124008229"
#   },
#   {
#    "category": "Musician/band",
#    "name": "Coke Boys Music",
#    "id": "270205439665423"
#   }
#  ]
# }
# Pepsi likes:
# 32,117,332
# Coke likes:
# 83,486,898

# %% [markdown]
# ## Example 6. Querying a page for its "feed" and "links" connections

# %%
pp(g.get_connections(pepsi_id, 'feed'))
pp(g.get_connections(pepsi_id, 'links'))

pp(g.get_connections(coke_id, 'feed'))
pp(g.get_connections(coke_id, 'links'))
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/56381779049/feed?access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&limit=25&until=1402589647",
#   "previous": "https://graph.facebook.com/v1.0/56381779049/feed?access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&limit=25&since=1402660527&__previous=1"
#  },
#  "data": [
#   {
#    "picture": "https://fbcdn-sphotos-h-a.akamaihd.net/hphotos-ak-xpa1/t1.0-9/q73/s480x480/1623551_10152479380223960_8583226737429089263_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTI4NTY1MTk1Mg==",
#       "before": "MTAwMDAwOTY0MjQzNjI1"
#      }
#     },
#     "data": [
#      {
#       "id": "100000964243625",
#       "name": "Kally Miller"
#      },
#      {
#       "id": "743894711",
#       "name": "Kathy Rudy"
#      },
#      {
#       "id": "1326947668",
#       "name": "Bonnie Richards"
#      },
#      {
#       "id": "100000141474934",
#       "name": "Carol Tuft"
#      },
#      {
#       "id": "1090776271",
#       "name": "Lynn Paramore"
#      },
#      {
#       "id": "1285651952",
#       "name": "Jennifer Read"
#      }
#     ]
#    },
#    "from": {
#     "id": "504018959",
#     "name": "Steven Chunk Watts"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "id": "1285651952",
#        "name": "Jennifer Read"
#       },
#       "message_tags": [
#        {
#         "length": 6,
#         "offset": 10,
#         "type": "user",
#         "id": "100001251253302",
#         "name": "Chesna"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T11:56:55+0000",
#       "message": "Kick butt Chesna!!! :)",
#       "id": "10152479380223960_10152479382843960",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152479380223960",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152479380223960",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T11:56:55+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbandroid",
#     "name": "Facebook for Android",
#     "id": "350685531728"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10152479380223960&set=o.56381779049&type=1",
#    "object_id": "10152479380223960",
#    "created_time": "2014-06-13T11:55:27+0000",
#    "message": "Pepsi pre-game before the horse show. #poa #Pepsi",
#    "type": "photo",
#    "id": "56381779049_10152479380223960",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "id": "100007903483645",
#     "name": "Rose Bellapigna"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152612859584050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152612859584050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T10:33:23+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T10:33:23+0000",
#    "message": "Like pepsi  brands",
#    "type": "status",
#    "id": "56381779049_10152612859584050"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQCm08xBJRG19RKz&w=154&h=154&url=https%3A%2F%2Fd14vy9ftykiink.cloudfront.net%2Fa%2Fimg%2Ffblogo.jpeg",
#    "from": {
#     "id": "612772174",
#     "name": "Alan Massingham"
#    },
#    "name": "Why are they bulldozing the rainforest?",
#    "caption": "action.sumofus.org",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152120473317175",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152120473317175",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T10:22:19+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://action.sumofus.org/a/pepsico-palm-oil/",
#    "created_time": "2014-06-13T10:22:19+0000",
#    "message": "Pepsi -- we're watching you. Commit to a STRONG palm oil policy. http://action.sumofus.org/a/pepsico-palm-oil/ #inyourpalm",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif",
#    "type": "link",
#    "id": "56381779049_10152120473317175",
#    "description": "If you eat snack food, you're gonna wanna read this."
#   },
#   {
#    "from": {
#     "id": "100004021331930",
#     "name": "Judith Lindeman"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152612819259050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152612819259050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T09:50:51+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T09:50:51+0000",
#    "message": "Just wondering what happen to  Pepsi Blue . It was my favorite?",
#    "type": "status",
#    "id": "56381779049_10152612819259050"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQCm08xBJRG19RKz&w=154&h=154&url=https%3A%2F%2Fd14vy9ftykiink.cloudfront.net%2Fa%2Fimg%2Ffblogo.jpeg",
#    "from": {
#     "id": "100000827531405",
#     "name": "Jannemieke de Groot"
#    },
#    "name": "Why are they bulldozing the rainforest?",
#    "caption": "action.sumofus.org",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/671441436226768",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/671441436226768",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T09:18:11+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://action.sumofus.org/a/pepsico-palm-oil/",
#    "created_time": "2014-06-13T09:18:11+0000",
#    "message": "Pepsi -- we're watching you. Commit to a STRONG palm oil policy. http://action.sumofus.org/a/pepsico-palm-oil/ #inyourpalm\n",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif",
#    "type": "link",
#    "id": "56381779049_671441436226768",
#    "description": "If you eat snack food, you're gonna wanna read this."
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQCm08xBJRG19RKz&w=154&h=154&url=https%3A%2F%2Fd14vy9ftykiink.cloudfront.net%2Fa%2Fimg%2Ffblogo.jpeg",
#    "from": {
#     "id": "100001523629136",
#     "name": "Chris Thornton"
#    },
#    "name": "Why are they bulldozing the rainforest?",
#    "caption": "action.sumofus.org",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/710388599021921",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/710388599021921",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T08:28:16+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://action.sumofus.org/a/pepsico-palm-oil/",
#    "created_time": "2014-06-13T08:28:16+0000",
#    "message": "Pepsi -- we're watching you. Commit to a STRONG palm oil policy. http://action.sumofus.org/a/pepsico-palm-oil/ #inyourpalm",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif",
#    "type": "link",
#    "id": "56381779049_710388599021921",
#    "description": "If you eat snack food, you're gonna wanna read this."
#   },
#   {
#    "from": {
#     "id": "100001523629136",
#     "name": "Chris Thornton"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152612742739050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152612742739050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T08:25:26+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T08:25:26+0000",
#    "message": "Pepsi -- we're watching you. Commit to a STRONG palm oil policy. http://action.sumofus.org/a/pepsico-palm-oil/ #inyourpalm",
#    "type": "status",
#    "id": "56381779049_10152612742739050"
#   },
#   {
#    "from": {
#     "id": "1497129106",
#     "name": "Vaughan Mavir"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152612625644050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152612625644050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T06:17:16+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T06:17:16+0000",
#    "message": "How long does it usually take for a rewards item to arrive???",
#    "type": "status",
#    "id": "56381779049_10152612625644050"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-xpf1/t1.0-9/q71/s480x480/10433239_10201805914621120_4643260975653136208_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MjI4MDA4OTk=",
#       "before": "MTAwMDAyMTAxNTMzMDI5"
#      }
#     },
#     "data": [
#      {
#       "id": "100002101533029",
#       "name": "Mary Holaday"
#      },
#      {
#       "id": "1582620060",
#       "name": "Lindsey Dvorak"
#      },
#      {
#       "id": "22800899",
#       "name": "Sara Michelle"
#      }
#     ]
#    },
#    "from": {
#     "id": "1579710058",
#     "name": "Kate Sandbo"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "OQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "id": "1579710058",
#        "name": "Kate Sandbo"
#       },
#       "message_tags": [
#        {
#         "length": 12,
#         "offset": 0,
#         "type": "user",
#         "id": "538385352",
#         "name": "Christy Wise"
#        }
#       ],
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:36:58+0000",
#       "message": "Christy Wise I tweeted, emailed and instagrammed them. This is my last resort before I get Beyonce on the case!",
#       "id": "10201805914621120_10201806134386614",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "538385352",
#        "name": "Christy Wise"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:42:29+0000",
#       "message": "They at least owe you a soda.",
#       "id": "10201805914621120_10201806152667071",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1640260963",
#        "name": "Tracy Long"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:29:57+0000",
#       "message": "Free Pepsi for life!",
#       "id": "10201805914621120_10201806115426140",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "22800899",
#        "name": "Sara Michelle"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:29:13+0000",
#       "message": "I think a bear just desperately needed a diet Pepsi. It happens!",
#       "id": "10201805914621120_10201806113506092",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "22800899",
#        "name": "Sara Michelle"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:45:49+0000",
#       "message": "Well crap, I thought you already moved back to WA. I bet he could slap on a Hawaiian shirt and help you out. Or maybe Beyonc\u00e9 is the best option for this one.",
#       "id": "10201805914621120_10201806169187484",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1579710058",
#        "name": "Kate Sandbo"
#       },
#       "message_tags": [
#        {
#         "length": 13,
#         "offset": 0,
#         "type": "user",
#         "id": "22800899",
#         "name": "Sara Michelle"
#        }
#       ],
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:44:28+0000",
#       "message": "Sara Michelle does Jesse concern himself with Hawaiian things?",
#       "id": "10201805914621120_10201806159267236",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "22800899",
#        "name": "Sara Michelle"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:38:56+0000",
#       "message": "",
#       "id": "10201805914621120_10201806141786799",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "538385352",
#        "name": "Christy Wise"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:35:11+0000",
#       "message": "Tweet at them, businesses respond better to twitter.",
#       "id": "10201805914621120_10201806129386489",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100000162244061",
#        "name": "Peggy Henry"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T02:55:55+0000",
#       "message": "Omg!",
#       "id": "10201805914621120_10201805992383064",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10201805914621120",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10201805914621120",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T03:45:49+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbiphone",
#     "name": "Facebook for iPhone",
#     "id": "6628568379"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10201805914621120&set=o.56381779049&type=1",
#    "object_id": "10201805914621120",
#    "created_time": "2014-06-13T02:32:26+0000",
#    "message": "This was found in a pack of Diet Pepsi I recently bought.  Not very safe.",
#    "type": "photo",
#    "id": "56381779049_10201805914621120",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-g-a.akamaihd.net/hphotos-ak-xpf1/t1.0-9/q80/s480x480/10366200_10201578614541860_2178611105239781965_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTYzNDQ2MzM2Ng==",
#       "before": "MTAwMDAwODE2NTgzMjcz"
#      }
#     },
#     "data": [
#      {
#       "id": "100000816583273",
#       "name": "Tammi Zultz"
#      },
#      {
#       "id": "100000236732742",
#       "name": "Steve Cooper"
#      },
#      {
#       "id": "528809401",
#       "name": "Sheila Hill"
#      },
#      {
#       "id": "1634463366",
#       "name": "Brandi Womack"
#      }
#     ]
#    },
#    "from": {
#     "id": "1672737630",
#     "name": "Christina Hoffpauir"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "Nw==",
#       "before": "MzQ="
#      },
#      "next": "https://graph.facebook.com/v1.0/56381779049_10201578614541860/comments?access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&limit=25&after=Nw%3D%3D"
#     },
#     "data": [
#      {
#       "from": {
#        "id": "100000816583273",
#        "name": "Tammi Zultz"
#       },
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2014-06-13T09:32:21+0000",
#       "message": "You are actually stupid enough to post this on fb? Really, how ignorant could you be? Fact 1. If that truck had origionally stopped there to make a delivery he can park it on the property any way he wants. 2. If he is on his DOT REQUIRED 30 minute break, it is illegal for him to drive that truck. 3. You hit a non moving vehicle, and obviously did not call the police and/or file a legal report and on fb, for everyone to see, you have just admitted your guilt to a hit and run. You will be lucky if Pepsi doesn't sue you for damages and defamation of character.",
#       "id": "10201578614541860_10201579936854917",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100003678548691",
#        "name": "Brett LeBlanc"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2014-06-13T10:10:43+0000",
#       "message": "Let us not forget the fact that no matter what, if she did not hit the truck but damaged private property such as bushes, flowers, curb, barricade, as I was trying to draw out what she hit... That she also admitted to having a child with her in the vehicle. If she did in fact hit the truck, then yes, it was a hit and run with a child.. Potentially endangerment.. We need all the facts, but the lack of what she brought to the table does let one make judgment that she is leaving it out initially as to not assume guilty...",
#       "id": "10201578614541860_10201580072858317",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1648896486",
#        "name": "Kate Macie Hill"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2014-06-13T09:45:53+0000",
#       "message": "Thank you, Tammi Zultz!!!!  You just stated everything going through my mind!",
#       "id": "10201578614541860_10201580020817016",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100000236732742",
#        "name": "Steve Cooper"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2014-06-13T11:21:38+0000",
#       "message": "You hit a parked vehicle and it's their fault?",
#       "id": "10201578614541860_10201580235662387",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100000816583273",
#        "name": "Tammi Zultz"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2014-06-13T09:58:00+0000",
#       "message": "What this person failed to say, is that, not understanding why this truck was just sitting there, she did not approach the driver and ask if there was any way possible they could move so they could depart the parking lot. People want to blame everyone else for the ignorance of their own actions, this person complains that the driver was not courteous, but then displays her own rage, when she didn't do it either.",
#       "id": "10201578614541860_10201580045017621",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100003678548691",
#        "name": "Brett LeBlanc"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2014-06-13T06:04:04+0000",
#       "message": "Well in all fairness, before I make accusations toward the driver or yourself, how exactly did your truck receive the damage? I don't know you nor do I know why this is in my news feed, but now I'm curious!",
#       "id": "10201578614541860_10201579457722939",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100001014313009",
#        "name": "Abby Rice"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2014-06-13T02:20:21+0000",
#       "message": "Did you call corporate with the truck number and time? Id file a complaint on the driver!!",
#       "id": "10201578614541860_10201578763545585",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100000350057968",
#        "name": "Jinny Tmq"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T10:27:14+0000",
#       "message": "You are a one funny lady!!!!\n You hit somebody and get mad at them for being there?\n I mean look at the size of that Pepsi truck... How exactly did you manage to \"not see it\" and hit it?",
#       "id": "10201578614541860_10201580103819091",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100003678548691",
#        "name": "Brett LeBlanc"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T06:16:45+0000",
#       "message": "Also did you call the police? A police report would be big in your case even if no ticket was issued due to being on private property",
#       "id": "10201578614541860_10201579493003821",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100003678548691",
#        "name": "Brett LeBlanc"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T06:07:25+0000",
#       "message": "Did this blue devil back into your new truck upon exiting his created spot? Or did you run into something or someone hit you in the process of the situation? Details would make the key points in receiving justice!",
#       "id": "10201578614541860_10201579470083248",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1634463366",
#        "name": "Brandi Womack"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T04:01:42+0000",
#       "message": "Someone is a Pepsi driver and needs to find another job so he can afford some big boy briefs and not some underroos.",
#       "id": "10201578614541860_10201579137154925",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100005978374084",
#        "name": "Jessica M Richie"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T02:23:58+0000",
#       "message": "Do not let this go! Stay on them until something is done about it!",
#       "id": "10201578614541860_10201578775305879",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "203600366",
#        "name": "Carissa Anelli"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T02:01:06+0000",
#       "message": "",
#       "id": "10201578614541860_10201578687103674",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "203600366",
#        "name": "Carissa Anelli"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T01:55:27+0000",
#       "message": "I got this",
#       "id": "10201578614541860_10201578668423207",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "203600366",
#        "name": "Carissa Anelli"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-13T01:51:13+0000",
#       "message": "Put ti on twitter as well",
#       "id": "10201578614541860_10201578647422682",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100000816583273",
#        "name": "Tammi Zultz"
#       },
#       "message_tags": [
#        {
#         "length": 13,
#         "offset": 8,
#         "type": "user",
#         "id": "100003678548691",
#         "name": "Brett LeBlanc"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T10:32:49+0000",
#       "message": "I agree Brett LeBlanc.",
#       "id": "10201578614541860_10201580113939344",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1672737630",
#        "name": "Christina Hoffpauir"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:54:35+0000",
#       "message": "Brett, exactly who are you talking to?",
#       "id": "10201578614541860_10201579120394506",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1672737630",
#        "name": "Christina Hoffpauir"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:23:02+0000",
#       "message": "The truck easily has $4000 worth of damage. I'll send you guys photos",
#       "id": "10201578614541860_10201579029752240",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1672737630",
#        "name": "Christina Hoffpauir"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:22:17+0000",
#       "message": "I'll pm you guys! They should absolutely be held accountable! Brenden was in the truck with me, we were there at a play center for other children.",
#       "id": "10201578614541860_10201579026592161",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100001014313009",
#        "name": "Abby Rice"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:20:42+0000",
#       "message": "Oh I can raise a lot of hell. I have a lot of free time. Just pm the place it happened and time!!! You have a baby with u and they need to realize there are truck stops to eat a dam meal not put others in danger!!!!",
#       "id": "10201578614541860_10201579020432007",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100000501031233",
#        "name": "Krystal Merz"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:10:43+0000",
#       "message": "So what happened to the truck?",
#       "id": "10201578614541860_10201578985711139",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1672737630",
#        "name": "Christina Hoffpauir"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T03:09:34+0000",
#       "message": "I will. I was so pissed! David stood with his arms outstretched in another photo to show just how far from the curb this jerk parked.",
#       "id": "10201578614541860_10201578982631062",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1672737630",
#        "name": "Christina Hoffpauir"
#       },
#       "message_tags": [
#        {
#         "length": 4,
#         "offset": 0,
#         "type": "user",
#         "id": "100001014313009",
#         "name": "Abby"
#        },
#        {
#         "length": 7,
#         "offset": 10,
#         "type": "user",
#         "id": "100005978374084",
#         "name": "Jessica"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T02:25:37+0000",
#       "message": "Abby  and Jessica  I will!  Thanks for the tip! And feel free to share and raise hell with me! =)",
#       "id": "10201578614541860_10201578780426007",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1672737630",
#        "name": "Christina Hoffpauir"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T02:07:13+0000",
#       "message": "I bet!",
#       "id": "10201578614541860_10201578708904219",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "203600366",
#        "name": "Carissa Anelli"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T02:04:43+0000",
#       "message": "But i tweeted mcdonalds a pic of weave in a sandwich and i got a response real quick",
#       "id": "10201578614541860_10201578700544010",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10201578614541860",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10201578614541860",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T11:21:38+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbandroid",
#     "name": "Facebook for Android",
#     "id": "350685531728"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10201578614541860&set=o.56381779049&type=1",
#    "object_id": "10201578614541860",
#    "created_time": "2014-06-13T01:47:53+0000",
#    "message": "One of your drivers parked so illegally and negligent that I couldn't completely turn out of this parking lot. He parked right next to the entrance/exit, nearly 6ft from the curb, in the way of all the traffic leaving and entering the parking lot. My new truck is damaged and your driver was at fault!",
#    "type": "photo",
#    "id": "56381779049_10201578614541860",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "category": "Musician/band",
#     "name": "Icona Pop",
#     "id": "119259988104027"
#    },
#    "message_tags": {
#     "45": [
#      {
#       "length": 5,
#       "offset": 45,
#       "type": "page",
#       "id": "56381779049",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611990629050",
#      "name": "Comment"
#     }
#    ],
#    "updated_time": "2014-06-12T22:41:14+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAyMjA1Nzg4OTcx",
#       "before": "MTAwMDAzNTM4OTcwNDQ0"
#      },
#      "next": "https://graph.facebook.com/v1.0/56381779049_10152611990629050/likes?access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&limit=25&after=MTAwMDAyMjA1Nzg4OTcx"
#     },
#     "data": [
#      {
#       "id": "100003538970444",
#       "name": "Jackie Chung"
#      },
#      {
#       "id": "100002112895640",
#       "name": "Dale Igcasenza"
#      },
#      {
#       "id": "100006613837208",
#       "name": "Claudia Aldana"
#      },
#      {
#       "id": "100003227719193",
#       "name": "Lemcam Chithan"
#      },
#      {
#       "id": "100008173323492",
#       "name": "\u00c0m\u00c1r \u00c2\u0142 \u00cdbr\u00e3h\u00eem"
#      },
#      {
#       "id": "100003395212115",
#       "name": "Daniel Ryan Ryan"
#      },
#      {
#       "id": "100001814541264",
#       "name": "Zul Fujiwara Takumi Haiqal"
#      },
#      {
#       "id": "1645362101",
#       "name": "Tammy Stevens"
#      },
#      {
#       "id": "100000363027834",
#       "name": "Serena Ilari"
#      },
#      {
#       "id": "100007925834171",
#       "name": "Emma Hentil\u00e4"
#      },
#      {
#       "id": "100002945506134",
#       "name": "Fanni Bajnok"
#      },
#      {
#       "id": "100002368902375",
#       "name": "\u00d6tv\u00f6s Panna"
#      },
#      {
#       "id": "100000467067694",
#       "name": "Kumico Yonemori"
#      },
#      {
#       "id": "100001789256695",
#       "name": "Indre Jokubauskaite"
#      },
#      {
#       "id": "100001870641711",
#       "name": "Richter Zs\u00f3fia"
#      },
#      {
#       "id": "100003406815124",
#       "name": "Shakya Chakraborty"
#      },
#      {
#       "id": "100004488212799",
#       "name": "Bart Wolterink"
#      },
#      {
#       "id": "100000462644572",
#       "name": "Borsodi Zolt\u00e1n"
#      },
#      {
#       "id": "100005818445051",
#       "name": "Michele Carandente"
#      },
#      {
#       "id": "100000691030447",
#       "name": "Rikke van Genechten"
#      },
#      {
#       "id": "100004043190364",
#       "name": "Ajay Kumar M"
#      },
#      {
#       "id": "100000592013269",
#       "name": "Ivan Glui\u0107"
#      },
#      {
#       "id": "100006466525996",
#       "name": "Jessy Aniceto"
#      },
#      {
#       "id": "100004494603956",
#       "name": "Sai Varun"
#      },
#      {
#       "id": "100002205788971",
#       "name": "Jez Losarim"
#      }
#     ]
#    },
#    "created_time": "2014-06-12T22:41:14+0000",
#    "message": "Stream our live performance at the B96 Radio Pepsi #SummerBash 6/14! http://b96.com",
#    "type": "status",
#    "id": "56381779049_10152611990629050",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "Mg==",
#       "before": "Ng=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "id": "100001058576781",
#        "name": "Allimalar Manimaran"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T08:08:47+0000",
#       "message": "Gd luck .....",
#       "id": "855998334430185_856187937744558",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100003993385383",
#        "name": "Sylvia Dwita Ningsih"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-13T00:31:16+0000",
#       "message": "(Y)",
#       "id": "855998334430185_856043617758990",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100003122150707",
#        "name": "Luciano Ferrari"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-12T23:02:31+0000",
#       "message": "COME TO ARGENTINA \u2661\u2661",
#       "id": "855998334430185_856007254429293",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100003339381148",
#        "name": "Anndie Valdez"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-06-12T22:51:19+0000",
#       "message": "<3 :3",
#       "id": "855998334430185_856002824429736",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100004869902474",
#        "name": "Jaaz Gonzalez"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-06-12T22:50:46+0000",
#       "message": "Argentina Love You <3 <3",
#       "id": "855998334430185_856002694429749",
#       "user_likes": false
#      }
#     ]
#    }
#   },
#   {
#    "from": {
#     "id": "100000869227028",
#     "name": "Matthew Maples"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611932529050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611932529050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-12T22:07:32+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-06-12T22:07:32+0000",
#    "message": "Put Pepsi Throwback IN 2 LITER BOTTLES!",
#    "type": "status",
#    "id": "56381779049_10152611932529050"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQDbu7YNTTxT3J-7&w=154&h=154&url=http%3A%2F%2Fmedia.salon.com%2F2014%2F06%2Fshutterstock_112755661.jpg",
#    "from": {
#     "id": "100000869227028",
#     "name": "Matthew Maples"
#    },
#    "name": "Supreme Court comes down hard on false pomegranate juice",
#    "caption": "www.salon.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/727604780611823",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/727604780611823",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-12T22:06:39+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://www.salon.com/2014/06/12/supreme_court_comes_down_hard_on_false_pomegranate_juice/",
#    "created_time": "2014-06-12T22:06:39+0000",
#    "message": "This is why I'm a Pepsi fan, and why Coke sucks!\n",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/y5/r/sXJx2UP7quc.png",
#    "type": "link",
#    "id": "56381779049_727604780611823",
#    "description": "The Justices ruled that Pom Wonderful can sue Coca-Cola for its misleading labels"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-e-a.akamaihd.net/hphotos-ak-xfp1/t1.0-9/q71/s480x480/10431537_1493625290855111_6692256248081402502_n.jpg",
#    "from": {
#     "id": "100006229637932",
#     "name": "Rodolfo Calvillo"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1493625290855111",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1493625290855111",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-12T21:34:01+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1493625290855111&set=o.56381779049&type=1",
#    "object_id": "1493625290855111",
#    "created_time": "2014-06-12T21:34:01+0000",
#    "message": "Change the pepsi logo to this",
#    "type": "photo",
#    "id": "56381779049_1493625290855111",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "application": {
#     "namespace": "fbandroid",
#     "name": "Facebook for Android",
#     "id": "350685531728"
#    },
#    "from": {
#     "id": "100000731421792",
#     "name": "Keith Ammerman"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611789174050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611789174050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-12T20:50:12+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-06-12T20:50:12+0000",
#    "message": "You guys gotta bring back Crystal Pepsi. It left a John Deere letter on my taste buds and hasn't been seen since. Don't you think it's time?! I long for in like the deserts miss the rain and oft dream of chugging is carbonated ecstasy while bumping Enya from a cheap stereo. Please. I need this to feel whole again.",
#    "type": "status",
#    "id": "56381779049_10152611789174050"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQCm08xBJRG19RKz&w=154&h=154&url=https%3A%2F%2Fd14vy9ftykiink.cloudfront.net%2Fa%2Fimg%2Ffblogo.jpeg",
#    "from": {
#     "id": "649773418",
#     "name": "Arron Waterworth"
#    },
#    "name": "Why are they bulldozing the rainforest?",
#    "caption": "action.sumofus.org",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152447675773419",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152447675773419",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-12T20:44:43+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://action.sumofus.org/a/pepsico-palm-oil/",
#    "created_time": "2014-06-12T20:44:43+0000",
#    "message": "Pepsi -- we're watching you. Commit to a STRONG palm oil policy. http://action.sumofus.org/a/pepsico-palm-oil/ #inyourpalm\n",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif",
#    "type": "link",
#    "id": "56381779049_10152447675773419",
#    "description": "If you eat snack food, you're gonna wanna read this."
#   },
#   {
#    "application": {
#     "namespace": "fbandroid",
#     "name": "Facebook for Android",
#     "id": "350685531728"
#    },
#    "from": {
#     "id": "100007220232872",
#     "name": "Holly Nielsen"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611639864050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611639864050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-12T19:27:53+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-06-12T19:27:53+0000",
#    "message": "I'm one of many that has loved Pepsi longer than I care to remember! \nRecently, since the changes of the looks I no longer love it. It's taste is  different.  I can tell and it may even have a hint of some diet substitute. I'm one that gets very severe headaches from products with saccrine  in them! I couldn't really put my finger on this until today! Lately I only buy pepsi when it's on sale . Otherwise I buy R C well pepsi is running a sale at our grocery store,  thought about getting some! I remembered the last sale how I stocked up on it. and then was so sick for over 24 hours!\nSo can you tell me? Upon changing the labels on Pepsi, did you change the pop to?",
#    "type": "status",
#    "id": "56381779049_10152611639864050"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQC4cxtM2omxLefF&w=130&h=130&url=http%3A%2F%2Fi1.ytimg.com%2Fvi%2F0LTSfmMd_Ug%2Fhqdefault.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAyNjMzODIwMjQz",
#       "before": "MTAwMDA2ODA5NDEwMjQ0"
#      },
#      "next": "https://graph.facebook.com/v1.0/56381779049_10152611614969050/likes?access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&limit=25&after=MTAwMDAyNjMzODIwMjQz"
#     },
#     "data": [
#      {
#       "id": "100006809410244",
#       "name": "Coretta Christler"
#      },
#      {
#       "id": "100000325327111",
#       "name": "Karla Peterson Hendrickson"
#      },
#      {
#       "id": "1246895095",
#       "name": "Terri Contreras Monroy"
#      },
#      {
#       "id": "1728866776",
#       "name": "Mayor Monument"
#      },
#      {
#       "id": "100004594871090",
#       "name": "Hiroshi Ueda"
#      },
#      {
#       "id": "100001645950228",
#       "name": "Koyama Yoshiaki"
#      },
#      {
#       "id": "100001470939773",
#       "name": "Steve Gomez"
#      },
#      {
#       "id": "1196950818",
#       "name": "Marta Gaitan"
#      },
#      {
#       "id": "100004480480610",
#       "name": "Danny Figueroa"
#      },
#      {
#       "id": "100001028164305",
#       "name": "Darlene Ortiz Ochoa"
#      },
#      {
#       "id": "100008245540508",
#       "name": "David Makle"
#      },
#      {
#       "id": "100003790069291",
#       "name": "Celso Urbina"
#      },
#      {
#       "id": "100006562324817",
#       "name": "Joe Jordan"
#      },
#      {
#       "id": "100003227910843",
#       "name": "Fukuda Wataru"
#      },
#      {
#       "id": "100001571515921",
#       "name": "Andy P. Baez"
#      },
#      {
#       "id": "100002233521310",
#       "name": "John Ytuarte"
#      },
#      {
#       "id": "100002437920144",
#       "name": "Gwendolyn Brookins"
#      },
#      {
#       "id": "100002031470243",
#       "name": "Deanne Gentile"
#      },
#      {
#       "id": "100001786869776",
#       "name": "Andrea Keller-Clark"
#      },
#      {
#       "id": "100003857475682",
#       "name": "Ruth Garcia"
#      },
#      {
#       "id": "100004100603801",
#       "name": "Rachel Hazel"
#      },
#      {
#       "id": "100007274441938",
#       "name": "Elizabeth Lisa Perez-Mejia"
#      },
#      {
#       "id": "100000209622522",
#       "name": "Omero Aceves"
#      },
#      {
#       "id": "100001614212690",
#       "name": "Jesus Perez"
#      },
#      {
#       "id": "100002633820243",
#       "name": "Alejandra Lopez"
#      }
#     ]
#    },
#    "from": {
#     "category": "Musician/band",
#     "name": "WAR THE BAND",
#     "id": "6109482426"
#    },
#    "name": "PEPSI MAX Drivers",
#    "message_tags": {
#     "14": [
#      {
#       "length": 5,
#       "offset": 14,
#       "type": "page",
#       "id": "56381779049",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611614969050",
#      "name": "Comment"
#     }
#    ],
#    "updated_time": "2014-06-12T19:13:31+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.youtube.com/watch?v=0LTSfmMd_Ug",
#    "source": "http://www.youtube.com/v/0LTSfmMd_Ug?autohide=1&version=3&autoplay=1",
#    "created_time": "2014-06-12T19:13:31+0000",
#    "message": "Remember this Pepsi Maxx Commercial ...\n#tbt \nhttps://www.youtube.com/watch?v=0LTSfmMd_Ug",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yj/r/v2OnaTyTQZE.gif",
#    "type": "video",
#    "id": "56381779049_10152611614969050",
#    "description": "One of the Best Ads of 2010! --BestAds.tv The premise of the new Pepsi MAX ad is the same from the 1995 original, one of the better loved commercials from Su..."
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQAXbJSGvtKZcgXf&w=154&h=154&url=http%3A%2F%2Fwww.mtv.com%2Fpromotions%2Fpepsi%2Fflock-to-unlock%2FMTV-LOGO.jpg",
#    "from": {
#     "category": "Tv network",
#     "name": "MTV",
#     "id": "7245371700"
#    },
#    "name": "Ed Sheeran - Flock To Unlock",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/y5/r/sXJx2UP7quc.png",
#    "message_tags": {
#     "11": [
#      {
#       "length": 10,
#       "offset": 11,
#       "type": "page",
#       "id": "9189674485",
#       "name": "Ed Sheeran"
#      }
#     ],
#     "93": [
#      {
#       "length": 5,
#       "offset": 93,
#       "type": "page",
#       "id": "56381779049",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152611614919050",
#      "name": "Comment"
#     }
#    ],
#    "updated_time": "2014-06-12T19:13:28+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Musician/band",
#       "name": "Ed Sheeran",
#       "id": "9189674485"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://on.mtv.com/1xPAPkv",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDA2NjkxNDQ4OTM5",
#       "before": "MTAwMDAxNDU3NDMzNTcx"
#      },
#      "next": "https://graph.facebook.com/v1.0/56381779049_10152611614919050/likes?access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&limit=25&after=MTAwMDA2NjkxNDQ4OTM5"
#     },
#     "data": [
#      {
#       "id": "100001457433571",
#       "name": "Claudia Tulisa Martinez"
#      },
#      {
#       "id": "100006988382541",
#       "name": "Iustin Crintea"
#      },
#      {
#       "id": "100004618175360",
#       "name": "Luis Alvarez"
#      },
#      {
#       "id": "100007549180904",
#       "name": "Sarabjeet Sidhu"
#      },
#      {
#       "id": "100003118810949",
#       "name": "Chinchin Usman"
#      },
#      {
#       "id": "100005317958643",
#       "name": "Jesus Alejandro Olzabal Llontop"
#      },
#      {
#       "id": "100000455342422",
#       "name": "Daryl Montes"
#      },
#      {
# ...
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQBtBqrsQ9-7V0sP&w=130&h=130&url=http%3A%2F%2Fi1.ytimg.com%2Fvi%2FbsZGBX5Vqbk%2Fhqdefault.jpg",
#    "from": {
#     "id": "100007334623898",
#     "name": "Ellis Dylan"
#    },
#    "name": "What happens if you put milk in Coca Cola",
#    "source": "http://www.youtube.com/v/bsZGBX5Vqbk?autohide=1&version=3&autoplay=1",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/1447715098816297",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/1447715098816297",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T13:20:07+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "link": "http://www.youtube.com/watch?v=bsZGBX5Vqbk",
#    "created_time": "2014-06-13T13:20:07+0000",
#    "message": "http://www.youtube.com/watch?v=bsZGBX5Vqbk",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yj/r/v2OnaTyTQZE.gif",
#    "type": "video",
#    "id": "40796308305_1447715098816297",
#    "description": "Here is an experiment to see what happens with Coca Cola if you mix it with milk, is an experiment that separate the ingredients from the water ."
#   },
#   {
#    "application": {
#     "name": "Facebook for Every Phone",
#     "id": "139682082719810"
#    },
#    "from": {
#     "id": "100003527318057",
#     "name": "Sanjeev Kumar"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317434828306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317434828306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T13:16:25+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T13:16:25+0000",
#    "message": "cool cool",
#    "type": "status",
#    "id": "40796308305_10153317434828306"
#   },
#   {
#    "from": {
#     "category": "Professional sports team",
#     "name": "Charlotte Hounds",
#     "category_list": [
#      {
#       "id": "1801",
#       "name": "Professional Sports Team"
#      }
#     ],
#     "id": "233893466620992"
#    },
#    "message_tags": {
#     "52": [
#      {
#       "length": 9,
#       "offset": 52,
#       "type": "page",
#       "id": "40796308305",
#       "name": "Coca-Cola"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317430598306",
#      "name": "Comment"
#     }
#    ],
#    "updated_time": "2014-06-13T13:14:10+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDA2MjgxNDY4NjA1",
#       "before": "MTMyNzk0NDcwNw=="
#      }
#     },
#     "data": [
#      {
#       "id": "1327944707",
#       "name": "Ray Bradham"
#      },
#      {
#       "id": "1542432884",
#       "name": "Paul Slater"
#      },
#      {
#       "id": "100006281468605",
#       "name": "Donnie Robinson"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T13:14:10+0000",
#    "message": "Who's excited to see Josh Daniel and Friends on the Coca-Cola Stage before tomorrow's game?! #ZeroK #ReleasetheHounds",
#    "type": "status",
#    "id": "40796308305_10153317430598306"
#   },
#   {
#    "from": {
#     "id": "100007526614224",
#     "name": "Mukiibi Henry"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317420273306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317420273306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T13:08:07+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T13:08:07+0000",
#    "message": "Ole! Ole! it's a friday sweet football match,its gonna be fire!!! #MEXICO V #CAMEROON. AT 7pm thax coco for dis #page.",
#    "type": "status",
#    "id": "40796308305_10153317420273306"
#   },
#   {
#    "picture": "https://fbcdn-photos-c-a.akamaihd.net/hphotos-ak-xfp1/t1.0-0/10312715_655812881155911_5394132430224677059_s.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAxNzkxOTY5NzY1",
#       "before": "MTAwMDAzMzAxNzc5OTY1"
#      },
#      "next": "https://graph.facebook.com/v1.0/40796308305_10153317413048306/likes?access_token=CAACEdEose0cBAHgq4ZB5Xe2k9r6LLRrHKb6ZC5ZAUN1gepVZAoZBoIlNTEyOKOqJNdm8ZAJdvoNbs5580Hhjo4s9efmxSWUGliQlMaFcTdG335kBubRRTVZAIZCO9tIyNLszQWtyQ2rTJZBBT6pXmVpMsgPqMptiZBzTRy46Qzll5qmpXoIlC3VlD7N2O3Y1dhVCkZD&limit=25&after=MTAwMDAxNzkxOTY5NzY1"
#     },
#     "data": [
#      {
#       "id": "100003301779965",
#       "name": "Basie\u0144ka S\u0142owik K\u0142odarska"
#      },
#      {
#       "id": "100000932783268",
#       "name": "Beata Korta"
#      },
#      {
#       "id": "100005689363581",
#       "name": "Adrian Kreft"
#      },
#      {
#       "id": "100004543502717",
#       "name": "Ania Podyma"
#      },
#      {
#       "id": "100002065362870",
#       "name": "Kamil Piec"
#      },
#      {
#       "id": "158404567511886",
#       "name": "Gdynia"
#      },
#      {
#       "id": "100002579066647",
#       "name": "Asia Gzubicka"
#      },
#      {
#       "id": "100005229430696",
#       "name": "Radek Krzeczkowski"
#      },
#      {
#       "id": "100004666484257",
#       "name": "Dariia Kulka"
#      },
#      {
#       "id": "100002678627165",
#       "name": "Robert Orlikowski"
#      },
#      {
#       "id": "100002318447773",
#       "name": "Wojtek Ratajczak"
#      },
#      {
#       "id": "100004556100968",
#       "name": "Sandra Ramotowska"
#      },
#      {
#       "id": "100005974183849",
#       "name": "Micha\u0142 Florczak"
#      },
#      {
#       "id": "100004748856438",
#       "name": "Weronika Dampc"
#      },
#      {
#       "id": "100000801680475",
#       "name": "Natalia Nalewajko"
#      },
#      {
#       "id": "100000652261785",
#       "name": "Patrycja Ko\u0142odziejczyk"
#      },
#      {
#       "id": "1362975862",
#       "name": "Tomek G\u00f3rajek"
#      },
#      {
#       "id": "100004444003294",
#       "name": "Mateusz Choroma\u0144ski"
#      },
#      {
#       "id": "100002984867583",
#       "name": "Patryk Korolczuk"
#      },
#      {
#       "id": "100003163269788",
#       "name": "Korina Zbyryt"
#      },
#      {
#       "id": "100002537915334",
#       "name": "Mi\u0142osz Grabarz"
#      },
#      {
#       "id": "100007637553733",
#       "name": "Przemek Dudzik"
#      },
#      {
#       "id": "100001861404101",
#       "name": "Anita Bodzianowska"
#      },
#      {
#       "id": "100005246082705",
#       "name": "Jakub Furma\u0144ski"
#      },
#      {
#       "id": "100001791969765",
#       "name": "Ola Kuzina"
#      }
#     ]
#    },
#    "from": {
#     "category": "Sports league",
#     "name": "Coca-Cola Cup Polska",
#     "id": "433605600043308"
#    },
#    "message_tags": {
#     "190": [
#      {
#       "length": 9,
#       "offset": 190,
#       "type": "page",
#       "id": "40796308305",
#       "name": "Coca-Cola"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317413048306",
#      "name": "Comment"
#     }
#    ],
#    "updated_time": "2014-06-13T13:03:34+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/CocaColaCupPolska/photos/pcb.655814197822446/655812881155911/?type=1&relevant_count=4",
#    "object_id": "655812881155911",
#    "created_time": "2014-06-13T13:03:34+0000",
#    "message": "Zdj\u0119cia z dachu Stadionu Miejskiego w Gdyni gdzie trwaj\u0105 rozgrywki. Wykonane przez Gdy\u0144ski O\u015brodek Sportu i Rekreacji. #CocaColaCup #CCCP #Gdynia #GOSiR #Ruchtoszczescie #Sport #Pilkanozna #Coca-Cola",
#    "type": "photo",
#    "id": "40796308305_10153317413048306",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yx/r/og8V99JVf8G.gif"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-e-a.akamaihd.net/hphotos-ak-xaf1/t1.0-9/q71/s480x480/10398046_10203098067324014_638093879054632547_n.jpg",
#    "from": {
#     "id": "1576236139",
#     "name": "Non Suzu"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10203098067324014",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10203098067324014",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T13:00:17+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbiphone",
#     "name": "Facebook for iPhone",
#     "id": "6628568379"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10203098067324014&set=o.40796308305&type=1",
#    "object_id": "10203098067324014",
#    "created_time": "2014-06-13T13:00:17+0000",
#    "message": "\u8b1d\u8b1d\u60a8 \u4eca\u5929\u6536\u5230\u4e86\u3002\n\u8b93\u6211\u8d85\u958b\u5fc3\u301c\u611f\u8b1d\u60a8",
#    "type": "photo",
#    "id": "40796308305_10203098067324014",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbcdn-profile-a.akamaihd.net/hprofile-ak-xpa1/t1.0-1/c0.0.200.200/p200x200/10338729_806733732672061_2697549379607172137_n.jpg",
#    "updated_time": "2014-06-13T12:54:35+0000",
#    "from": {
#     "id": "100004061196458",
#     "name": "Rana Umer"
#    },
#    "name": "SaDa Shehar Faisalabad",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/492934484185254",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/492934484185254",
#      "name": "Like"
#     }
#    ],
#    "properties": [
#     {
#      "text": "1,218 like this",
#      "name": "Community"
#     }
#    ],
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/pages/SaDa-Shehar-Faisalabad/805028532842581",
#    "created_time": "2014-06-13T12:54:35+0000",
#    "message": "Plzz like this page..",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif",
#    "type": "link",
#    "id": "40796308305_492934484185254",
#    "description": "Faisalabad Great Place In The World"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-a-a.akamaihd.net/hphotos-ak-xpf1/t1.0-9/q71/s480x480/10394106_867107749985667_6011253509665976387_n.jpg",
#    "from": {
#     "category": "Retail and consumer merchandise",
#     "name": "College Souvenir Shop",
#     "id": "561634987199613"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/867107749985667",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/867107749985667",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T12:50:28+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=867107749985667&set=o.40796308305&type=1",
#    "object_id": "867107749985667",
#    "created_time": "2014-06-13T12:50:28+0000",
#    "message": "https://www.facebook.com/collegesouvenirshop?ref=hl",
#    "type": "photo",
#    "id": "40796308305_867107749985667",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "id": "100007167248381",
#     "name": "Uwa Ogiesoba"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317382298306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317382298306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T12:46:13+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T12:46:13+0000",
#    "message": "I love this drink",
#    "type": "status",
#    "id": "40796308305_10153317382298306"
#   },
#   {
#    "from": {
#     "id": "1686553574",
#     "name": "Ricardo Pereira"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317373278306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317373278306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T12:41:07+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T12:41:07+0000",
#    "message": "Beleza, ganhei a promo geldeira, agora so tomar uma bem geladinha.youp",
#    "type": "status",
#    "id": "40796308305_10153317373278306"
#   },
#   {
#    "application": {
#     "name": "BlackBerry Smartphones App",
#     "id": "2254487659"
#    },
#    "from": {
#     "id": "1310779168",
#     "name": "Mark Anthony Smith"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317371938306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317371938306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T12:40:10+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T12:40:10+0000",
#    "message": "So bad for your health!!",
#    "type": "status",
#    "id": "40796308305_10153317371938306"
#   },
#   {
#    "from": {
#     "id": "1222948402",
#     "name": "Lenita Silva de Paula"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317336088306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317336088306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T12:19:32+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T12:19:32+0000",
#    "message": "Cadastrei os c\u00f3digos das tampinhas via SMS e n\u00e3o constam no meu extrato site da promo\u00e7\u00e3o \"Juntos em todas as copas\". o que acontece???",
#    "type": "status",
#    "id": "40796308305_10153317336088306"
#   },
#   {
#    "from": {
#     "id": "1586378827",
#     "name": "Away Ngaco"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317335668306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153317335668306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-06-13T12:19:18+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-06-13T12:19:18+0000",
#    "message": "payah promo fifa d alfa g sesuai brosur",
#    "type": "status",
#    "id": "40796308305_10153317335668306"
#   }
#  ]
# }
# {
#  "data": []
# }

# %% [markdown]
# ## Example 7. Querying for all of your friends' likes

# %%
# First, let's query for all of the likes in your social
# network and store them in a slightly more convenient
# data structure as a dictionary keyed on each friend's
# name. We'll use a dictionary comprehension to iterate
# over the friends and build up the likes in an intuitive
# way, although the new "field expansion" feature could 
# technically do the job in one fell swoop as follows:
#
# g.get_object('me', fields='id,name,friends.fields(id,name,likes)')
#
# See Appendix C for more information on Python tips such as
# dictionary comprehensions

friends = g.get_connections("me", "friends")['data']

likes = { friend['name'] : g.get_connections(friend['id'], "likes")['data'] 
          for friend in friends }

print likes
# Out:
# {'Andrew Chien': [{'category': 'Non-profit organization', 'created_time': '2013-12-04T22:08:03+0000', 'name': 'Breast Intentions', 'category_list': [{'id': '2603', 'name': 'Non-Profit Organization'}], 'id': '199062023491021'}, {'category': 'Product/service', 'created_time': '2013-09-30T11:30:23+0000', 'name': 'Virgin Mobile USA', 'id': '176824455678893'}, {'category': 'Reference website', 'created_time': '2013-08-08T14:34:42+0000', 'name': 'Talk To Me In Korean', 'id': '436808480033'}, {'category': 'Computers/technology', 'created_time': '2013-07-11T04:55:12+0000', 'name': 'Jisun Jung Fan Club', 'id': '158604414323256'}, {'category': 'Community', 'created_time': '2013-06-11T02:12:53+0000', 'name': 'Lee Gao Fan Club', 'id': '477767132305174'}, {'category': 'Computers/technology', 'created_time': '2012-09-02T18:38:51+0000', 'name': 'PennApps', 'id': '103140939743548'}, {'category': 'Tv show', 'created_time': '2012-06-11T20:09:44+0000', 'name': 'Shaq Vs.', 'id': '109392885745184'}, {'category': 'Community organization', 'created_time': '2012-05-08T15:30:59+0000', 'name': 'B.L.U.E. Shuttle', 'id': '221708267944720'}, {'category': 'Musical genre', 'created_time': '2012-04-08T02:25:37+0000', 'name': 'KPop', 'id': '110376505656631'}, {'category': 'Musical genre', 'created_time': '2012-04-08T02:25:36+0000', 'name': 'Dubstep', 'id': '109592655734436'}, {'category': 'Musical genre', 'created_time': '2012-04-08T02:25:34+0000', 'name': 'New age', 'id': '107674035922695'}, {'category': 'Community', 'created_time': '2012-02-08T23:05:38+0000', 'name': 'Cornell Memes', 'id': '243421265740930'}, {'category': 'Product/service', 'created_time': '2011-12-08T06:04:32+0000', 'name': 'Hackathon', 'id': '167580640987'}, {'category': 'Community', 'created_time': '2011-12-06T01:21:31+0000', 'name': 'Trust Me, I\'m an "Engineer"', 'id': '290539813359'}, {'category': 'Electronics', 'created_time': '2011-11-25T18:56:58+0000', 'name': 'CPeel.net', 'id': '296287330394377'}, {'category': 'Organization', 'created_time': '2011-11-04T00:45:50+0000', 'name': 'Cornell Concert Commission', 'category_list': [{'id': '198503866828628', 'name': 'Organization'}], 'id': '115146633978'}, {'category': 'Education', 'created_time': '2011-10-27T19:22:21+0000', 'name': 'Cornell ECE', 'category_list': [{'id': '151676848220295', 'name': 'Education'}], 'id': '148261318553588'}, {'category': 'Software', 'created_time': '2011-10-15T23:55:59+0000', 'name': 'Camp Hackathon', 'id': '114869201895800'}, {'category': 'Education', 'created_time': '2011-09-13T03:49:53+0000', 'name': 'High Technology High School', 'category_list': [{'id': '151676848220295', 'name': 'Education'}], 'id': '218788884843140'}, {'category': 'Tv show', 'created_time': '2011-09-10T19:24:21+0000', 'name': 'Game of Thrones', 'id': '74133697733'}, {'category': 'Book', 'created_time': '2011-09-08T19:35:04+0000', 'name': 'What Are Books', 'id': '106787402679449'}, {'category': 'Video game', 'created_time': '2011-09-08T06:25:48+0000', 'name': 'The Legend of Zelda: Twilight Princess', 'id': '112139085465448'}, {'category': 'Tv show', 'created_time': '2011-09-08T06:22:25+0000', 'name': 'Robot Chicken', 'id': '112128358799672'}, {'category': 'Video game', 'created_time': '2011-09-08T06:22:25+0000', 'name': 'Super Smash Bros. Melee', 'id': '107737149249821'}, {'category': 'Video game', 'created_time': '2011-09-08T06:22:25+0000', 'name': 'SSX Tricky', 'id': '106071139424051'}], 'Winston Hsu': [], 'Xiaohan Zhang': [{'category': 'Professional sports team', 'created_time': '2014-03-01T07:26:03+0000', 'name': 'LA Lakers', 'id': '144917055340'}, {'category': 'Professional sports team', 'created_time': '2013-08-14T07:48:34+0000', 'name': 'Invictus Gaming -iG', 'id': '380654645334156'}], 'Steven Wong': [{'category': 'Community', 'created_time': '2013-03-11T15:18:45+0000', 'name': 'Sick Spits', 'id': '457468014321643'}, {'category': 'Musician/band', 'created_time': '2013-01-31T07:48:05+0000', 'name': 'Kaotonix', 'id': '3446152856039 ...

# %% [markdown]
# ## Example 8. Calculating the most popular likes among your friends

# %%
# Analyze all likes from friendships for frequency

# pip install prettytable
from prettytable import PrettyTable
from collections import Counter
friends_likes = Counter([like['name']
                         for friend in likes 
                           for like in likes[friend]
                               if like.get('name')])

pt = PrettyTable(field_names=['Name', 'Freq'])
pt.align['Name'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(fl) for fl in friends_likes.most_common(10) ]

print 'Top 10 likes amongst friends'
print pt
# Out:
# Top 10 likes amongst friends
# +-----------------------------------------+------+
# | Name                                    | Freq |
# +-----------------------------------------+------+
# | KPop                                    |    1 |
# | Daft Punk                               |    1 |
# | Euro Bake World                         |    1 |
# | #BetterCities                           |    1 |
# | Pogoseat                                |    1 |
# | CPeel.net                               |    1 |
# | Billy Joel                              |    1 |
# | PennApps                                |    1 |
# | United Nations Association-USA East Bay |    1 |
# | 1 Million Cups Orlando                  |    1 |
# +-----------------------------------------+------+

# %% [markdown]
# ## Example 9. Calculating the most popular categories for likes among your friends

# %%
# Analyze all like categories by frequency

friends_likes_categories = Counter([like['category'] 
                                    for friend in likes 
                                      for like in likes[friend]])

pt = PrettyTable(field_names=['Category', 'Freq'])
pt.align['Category'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(flc) for flc in friends_likes_categories.most_common(10) ]

print "Top 10 like categories for friends"
print pt
# Out:
# Top 10 like categories for friends
# +-------------------------+------+
# | Category                | Freq |
# +-------------------------+------+
# | Musician/band           |   12 |
# | Community               |   12 |
# | Tv show                 |    6 |
# | Video game              |    5 |
# | Musical genre           |    3 |
# | Product/service         |    3 |
# | Non-profit organization |    3 |
# | Computers/technology    |    3 |
# | Artist                  |    3 |
# | Organization            |    3 |
# +-------------------------+------+

# %% [markdown]
# ## Example 10. Calculating the number of likes for each friend and sorting by frequency

# %%
# Build a frequency distribution of number of likes by 
# friend with a dictionary comprehension and sort it in 
# descending order

from operator import itemgetter

num_likes_by_friend = { friend : len(likes[friend]) 
                        for friend in likes }


pt = PrettyTable(field_names=['Friend', 'Num Likes'])
pt.align['Friend'], pt.align['Num Likes'] = 'l', 'r'
[ pt.add_row(nlbf) 
  for nlbf in sorted(num_likes_by_friend.items(), 
                     key=itemgetter(1), 
                     reverse=True) ]

print "Number of likes per friend"
print pt
# Out:
# Number of likes per friend
# +----------------+-----------+
# | Friend         | Num Likes |
# +----------------+-----------+
# | Andrew Chien   |        25 |
# | Jayson Poon    |        25 |
# | John Li        |        25 |
# | Steven Wong    |         4 |
# | Xiaohan Zhang  |         2 |
# | Alex Hü        |         2 |
# | Winston Hsu    |         0 |
# | Brittany Cheng |         0 |
# +----------------+-----------+

# %% [markdown]
# ## Example 11. Finding common likes between an ego and its friendships in a social network

# %%
# Which of your likes are in common with which friends?
my_likes = [ like['name'] 
             for like in g.get_connections("me", "likes")['data'] ]

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((ml,)) for ml in my_likes ]
print "My likes"
print pt

# Use the set intersection as represented by the ampersand
# operator to find common likes.

common_likes = list(set(my_likes) & set(friends_likes))

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((cl,)) for cl in common_likes ]
print
print "My common likes with friends"
print pt
# Out:
# My likes
# +----------------------------------------------------------------------------+
# | Name                                                                       |
# +----------------------------------------------------------------------------+
# | Hippie-Korea~ the Community for Fun, Culture, Network and more about Korea |
# | Eddie Chun                                                                 |
# | Sebastien Dupuis                                                           |
# | Official: David Mitchell - Author                                          |
# | Haruki Murakami                                                            |
# | David Mitchell (author)                                                    |
# | Berkeley Innovation                                                        |
# | Ultari Guest House                                                         |
# | BERC Undergrad                                                             |
# | Hayao Miyazaki                                                             |
# | Teddy Rice                                                                 |
# | Theatre Rice!                                                              |
# | CampusBookRentals.com                                                      |
# | The Killers                                                                |
# | Ben Issler                                                                 |
# | UC Berkeley SF AIDS Walk Team                                              |
# | John Mayer                                                                 |
# | Randomly laughing  because you remembered something funny.                 |
# | City and County of San Francisco                                           |
# +----------------------------------------------------------------------------+
#
# My common likes with friends
# +------+
# | Name |
# +------+
# +------+

# %% [markdown]
# ## Example 12. Calculating the friends most similar to an ego in a social network

# %%
# Which of your friends like things that you like?

similar_friends = [ (friend, friend_like['name']) 
                     for friend, friend_likes in likes.items()
                       for friend_like in friend_likes
                         if friend_like.get('name') in common_likes ]


# Filter out any possible duplicates that could occur

ranked_friends = Counter([ friend for (friend, like) in list(set(similar_friends)) ])


pt = PrettyTable(field_names=["Friend", "Common Likes"])
pt.align["Friend"], pt.align["Common Likes"] = 'l', 'r'
[ pt.add_row(rf) 
  for rf in sorted(ranked_friends.items(), 
                   key=itemgetter(1), 
                   reverse=True) ]
print "My similar friends (ranked)"
print pt

# Also keep in mind that you have the full range of plotting
# capabilities available to you. A quick histogram that shows
# how many friends.

plt.hist(ranked_friends.values())
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')

# Keep in mind that you can customize the binning
# as desired. See http://matplotlib.org/api/pyplot_api.html

# For example...

plt.figure() # Display the previous plot
plt.hist(ranked_friends.values(),
          bins=arange(1,max(ranked_friends.values()),1))
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')
plt.figure() # Display the working plot
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-92c4586daa39> in <module>()
#      25 # how many friends.
#      26
# ---> 27 plt.hist(ranked_friends.values())
#      28 plt.xlabel('Bins (number of friends with shared likes)')
#      29 plt.ylabel('Number of shared likes in each bin')
#
# C:\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2825                       histtype=histtype, align=align, orientation=orientation,
#    2826                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2827                       stacked=stacked, **kwargs)
#    2828         draw_if_interactive()
#    2829     finally:
#
# C:\Anaconda\lib\site-packages\matplotlib\axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8247         # Massage 'x' for processing.
#    8248         # NOTE: Be sure any changes here is also done below to 'weights'
# -> 8249         if isinstance(x, np.ndarray) or not iterable(x[0]):
#    8250             # TODO: support masked arrays;
#    8251             x = np.asarray(x)
#
# IndexError: list index out of range
# My similar friends (ranked)
# +--------+--------------+
# | Friend | Common Likes |
# +--------+--------------+
# +--------+--------------+

# %% [markdown]
# ## Example 13. Constructing a graph of mutual friendships

# %%
import networkx as nx # pip install networkx
import requests # pip install requests

friends = [ (friend['id'], friend['name'],)
                for friend in g.get_connections('me', 'friends')['data'] ]

url = 'https://graph.facebook.com/me/mutualfriends/%s?access_token=%s'

mutual_friends = {} 
print mutual_friends

# This loop spawns a separate request for each iteration, so
# it may take a while. Optimization with a thread pool or similar
# technique would be possible.
for friend_id, friend_name in friends:
    r = requests.get(url % (friend_id, ACCESS_TOKEN,) )
    response_data = json.loads(r.content)['data']
    mutual_friends[friend_name] = [ data['name'] 
                                    for data in response_data ]
    
nxg = nx.Graph()

[ nxg.add_edge('me', mf) for mf in mutual_friends ]

[ nxg.add_edge(f1, f2) 
  for f1 in mutual_friends 
      for f2 in mutual_friends[f1] ]

# Explore what's possible to do with the graph by 
# typing nxg.<tab> or executing a new cell with 
# the following value in it to see some pydoc on nxg
print nxg
# Out:
# {}

# %% [markdown]
# ## Example 14. Finding and analyzing cliques in a graph of mutual friendships

# %%
# Finding cliques is a hard problem, so this could
# take a while for large graphs.
# See http://en.wikipedia.org/wiki/NP-complete and 
# http://en.wikipedia.org/wiki/Clique_problem.

cliques = [c for c in nx.find_cliques(nxg)]

num_cliques = len(cliques)

clique_sizes = [len(c) for c in cliques]
max_clique_size = max(clique_sizes)
avg_clique_size = sum(clique_sizes) / num_cliques

max_cliques = [c for c in cliques if len(c) == max_clique_size]

num_max_cliques = len(max_cliques)

max_clique_sets = [set(c) for c in max_cliques]
friends_in_all_max_cliques = list(reduce(lambda x, y: x.intersection(y),
                                  max_clique_sets))

print 'Num cliques:', num_cliques
print 'Avg clique size:', avg_clique_size
print 'Max clique size:', max_clique_size
print 'Num max cliques:', num_max_cliques
print
print 'Friends in all max cliques:'
print json.dumps(friends_in_all_max_cliques, indent=1)
print
print 'Max cliques:'
print json.dumps(max_cliques, indent=1)
# Out:
# Num cliques: 8
# Avg clique size: 2
# Max clique size: 2
# Num max cliques: 8
#
# Friends in all max cliques:
# [
#  "me"
# ]
#
# Max cliques:
# [
#  [
#   "me",
#   "Andrew Chien"
#  ],
#  [
#   "me",
#   "Winston Hsu"
#  ],
#  [
#   "me",
#   "Xiaohan Zhang"
#  ],
#  [
#   "me",
#   "Steven Wong"
#  ],
#  [
#   "me",
#   "Alex H\u00fc"
#  ],
#  [
#   "me",
#   "Jayson Poon"
#  ],
#  [
#   "me",
#   "Brittany Cheng"
#  ],
#  [
#   "me",
#   "John Li"
#  ]
# ]

# %% [markdown]
# ## Example 15. Serializing a NetworkX graph to a file for consumption by D3

# %%
from networkx.readwrite import json_graph

nld = json_graph.node_link_data(nxg)

json.dump(nld, open('resources/ch02-facebook/viz/force.json','w'))

# %% [markdown]
# Note: You may need to implement some filtering on the NetworkX graph before writing it out to a file for display in D3, and for more than dozens of nodes, it may not be reasonable to render a meaningful visualization without some JavaScript hacking on its parameters. View the JavaScript source in [force.html](files/resources/ch02-facebook/viz/force.html) for some of the details.

# %% [markdown]
# ## Example 16. Visualizing a mutual friendship graph with D3

# %%
from IPython.display import IFrame
from IPython.core.display import display

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

viz_file = 'files/resources/ch02-facebook/viz/force.html'

display(IFrame(viz_file, '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="files/resources/ch02-facebook/viz/force.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
