# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'bGRIdtMcJZN9VW8nsaAurcKMF'
CONSUMER_SECRET ='UI9dwxIJCEBlUTUefOIqgLukoSIaCxxFisVWfcEoyAALKYW5rD'
OAUTH_TOKEN = '519157968-TryX7iHzqaJcayMLe6pMTNwxtGZtAuajXCpKcH74'
OAUTH_TOKEN_SECRET = 'U3t6RFhoIH68vtGl0bFqgkz4HJoZiVMQWMVC4fGxBq59L'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x0000000004E5EBE0>

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977
SEOUL_WOE_ID= 1132599

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
seoul_trends= twitter_api.trends.place(_id=SEOUL_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2014-12-14T12:28:47Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23PeopleWhoMadeMy2014', u'query': u'%23PeopleWhoMadeMy2014', u'name': u'#PeopleWhoMadeMy2014', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23%C3%96zg%C3%BCrBelaParalelSusacak', u'query': u'%23%C3%96zg%C3%BCrBelaParalelSusacak', u'name': u'#\xd6zg\xfcrBelaParalelSusacak', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23AyatRejectKejam', u'query': u'%23AyatRejectKejam', u'name': u'#AyatRejectKejam', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23ZamanTemizlikZaman%C4%B1', u'query': u'%23ZamanTemizlikZaman%C4%B1', u'name': u'#ZamanTemizlikZaman\u0131', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23RoIndiaRo', u'query': u'%23RoIndiaRo', u'name': u'#RoIndiaRo', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22El+Arabi%22', u'query': u'%22El+Arabi%22', u'name': u'El Arabi', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22JaDine+BLUEming+Loveteam%22', u'query': u'%22JaDine+BLUEming+Loveteam%22', u'name': u'JaDine BLUEming Loveteam', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Juventus+1-0+Sampdoria%22', u'query': u'%22Juventus+1-0+Sampdoria%22', u'name': u'Juventus 1-0 Sampdoria', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Ekrem', u'query': u'Ekrem', u'name': u'Ekrem', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Ne%C5%9Fe+D%C3%BCzel%22', u'query': u'%22Ne%C5%9Fe+D%C3%BCzel%22', u'name': u'Ne\u015fe D\xfczel', u'promoted_content': None}], u'as_of': u'2014-12-14T12:35:04Z', u'locations': [{u'woeid': 1, u'name': u'Worldwide'}]}]
#
# [{u'created_at': u'2014-12-14T12:28:47Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23PeopleWhoMadeMy2014', u'query': u'%23PeopleWhoMadeMy2014', u'name': u'#PeopleWhoMadeMy2014', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23RuinAn80sSitcom', u'query': u'%23RuinAn80sSitcom', u'name': u'#RuinAn80sSitcom', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23MeteorologicalFilms', u'query': u'%23MeteorologicalFilms', u'name': u'#MeteorologicalFilms', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23SurviveTheNight', u'query': u'%23SurviveTheNight', u'name': u'#SurviveTheNight', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23MillionsMarchNYC', u'query': u'%23MillionsMarchNYC', u'name': u'#MillionsMarchNYC', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Wolf+of+Wall+Street%22', u'query': u'%22Wolf+of+Wall+Street%22', u'name': u'Wolf of Wall Street', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Waffle+House%22', u'query': u'%22Waffle+House%22', u'name': u'Waffle House', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Marcus+Mariota%22', u'query': u'%22Marcus+Mariota%22', u'name': u'Marcus Mariota', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Finna', u'query': u'Finna', u'name': u'Finna', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Heisman', u'query': u'Heisman', u'name': u'Heisman', u'promoted_content': None}], u'as_of': u'2014-12-14T12:35:05Z', u'locations': [{u'woeid': 23424977, u'name': u'United States'}]}]

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print json.dumps(world_trends, indent=1)
print json.dumps(seoul_trends, indent=1)
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2014-12-14T12:28:47Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23PeopleWhoMadeMy2014",
#     "query": "%23PeopleWhoMadeMy2014",
#     "name": "#PeopleWhoMadeMy2014",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%C3%96zg%C3%BCrBelaParalelSusacak",
#     "query": "%23%C3%96zg%C3%BCrBelaParalelSusacak",
#     "name": "#\u00d6zg\u00fcrBelaParalelSusacak",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AyatRejectKejam",
#     "query": "%23AyatRejectKejam",
#     "name": "#AyatRejectKejam",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ZamanTemizlikZaman%C4%B1",
#     "query": "%23ZamanTemizlikZaman%C4%B1",
#     "name": "#ZamanTemizlikZaman\u0131",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RoIndiaRo",
#     "query": "%23RoIndiaRo",
#     "name": "#RoIndiaRo",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22El+Arabi%22",
#     "query": "%22El+Arabi%22",
#     "name": "El Arabi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22JaDine+BLUEming+Loveteam%22",
#     "query": "%22JaDine+BLUEming+Loveteam%22",
#     "name": "JaDine BLUEming Loveteam",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Juventus+1-0+Sampdoria%22",
#     "query": "%22Juventus+1-0+Sampdoria%22",
#     "name": "Juventus 1-0 Sampdoria",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Ekrem",
#     "query": "Ekrem",
#     "name": "Ekrem",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ne%C5%9Fe+D%C3%BCzel%22",
#     "query": "%22Ne%C5%9Fe+D%C3%BCzel%22",
#     "name": "Ne\u015fe D\u00fczel",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-12-14T12:35:04Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
# [
#  {
#   "created_at": "2014-12-14T12:28:49Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23%EC%9E%90%EC%BA%90%EA%B0%80_%EB%88%88_%EC%98%A4%EB%8A%94%EB%82%A0_%ED%95%98%EB%8A%94%EC%9D%BC",
#     "query": "%23%EC%9E%90%EC%BA%90%EA%B0%80_%EB%88%88_%EC%98%A4%EB%8A%94%EB%82%A0_%ED%95%98%EB%8A%94%EC%9D%BC",
#     "name": "#\uc790\uce90\uac00_\ub208_\uc624\ub294\ub0a0_\ud558\ub294\uc77c",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%ED%97%88%EA%B7%B8%EB%8D%B0%EC%9D%B4",
#     "query": "%ED%97%88%EA%B7%B8%EB%8D%B0%EC%9D%B4",
#     "name": "\ud5c8\uadf8\ub370\uc774",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EC%B5%9C%EA%B2%BD%EC%9C%84",
#     "query": "%EC%B5%9C%EA%B2%BD%EC%9C%84",
#     "name": "\ucd5c\uacbd\uc704",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%ED%83%90%EB%9D%BC%EB%B0%B0_%EA%B1%B0%EC%A7%93%EB%A7%90_%EB%8C%80%EC%A0%84",
#     "query": "%23%ED%83%90%EB%9D%BC%EB%B0%B0_%EA%B1%B0%EC%A7%93%EB%A7%90_%EB%8C%80%EC%A0%84",
#     "name": "#\ud0d0\ub77c\ubc30_\uac70\uc9d3\ub9d0_\ub300\uc804",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EB%9F%B0%EB%8B%9D%EB%A7%A8",
#     "query": "%EB%9F%B0%EB%8B%9D%EB%A7%A8",
#     "name": "\ub7f0\ub2dd\ub9e8",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EA%B9%80%EC%9A%B0%EB%B9%88",
#     "query": "%EA%B9%80%EC%9A%B0%EB%B9%88",
#     "name": "\uae40\uc6b0\ube48",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EC%9D%B4%ED%98%84%EC%9A%B0",
#     "query": "%EC%9D%B4%ED%98%84%EC%9A%B0",
#     "name": "\uc774\ud604\uc6b0",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EB%8F%99%EA%B3%B5%EC%A7%80%EC%A7%84",
#     "query": "%EB%8F%99%EA%B3%B5%EC%A7%80%EC%A7%84",
#     "name": "\ub3d9\uacf5\uc9c0\uc9c4",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EC%83%9D%EC%9D%BC%EC%B6%95%ED%95%98",
#     "query": "%EC%83%9D%EC%9D%BC%EC%B6%95%ED%95%98",
#     "name": "\uc0dd\uc77c\ucd95\ud558",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%EC%9A%B0%EB%A6%AC%EC%9E%A5%EB%A5%B4_%EB%AA%85%EB%8C%80%EC%82%AC",
#     "query": "%23%EC%9A%B0%EB%A6%AC%EC%9E%A5%EB%A5%B4_%EB%AA%85%EB%8C%80%EC%82%AC",
#     "name": "#\uc6b0\ub9ac\uc7a5\ub974_\uba85\ub300\uc0ac",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-12-14T12:36:59Z",
#   "locations": [
#    {
#     "woeid": 1132599,
#     "name": "Seoul"
#    }
#   ]
#  }
# ]
# [
#  {
#   "created_at": "2014-12-14T12:28:47Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23PeopleWhoMadeMy2014",
#     "query": "%23PeopleWhoMadeMy2014",
#     "name": "#PeopleWhoMadeMy2014",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RuinAn80sSitcom",
#     "query": "%23RuinAn80sSitcom",
#     "name": "#RuinAn80sSitcom",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MeteorologicalFilms",
#     "query": "%23MeteorologicalFilms",
#     "name": "#MeteorologicalFilms",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SurviveTheNight",
#     "query": "%23SurviveTheNight",
#     "name": "#SurviveTheNight",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MillionsMarchNYC",
#     "query": "%23MillionsMarchNYC",
#     "name": "#MillionsMarchNYC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Wolf+of+Wall+Street%22",
#     "query": "%22Wolf+of+Wall+Street%22",
#     "name": "Wolf of Wall Street",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Waffle+House%22",
#     "query": "%22Waffle+House%22",
#     "name": "Waffle House",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Marcus+Mariota%22",
#     "query": "%22Marcus+Mariota%22",
#     "name": "Marcus Mariota",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Finna",
#     "query": "Finna",
#     "name": "Finna",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Heisman",
#     "query": "Heisman",
#     "name": "Heisman",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-12-14T12:35:05Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends[0]['trends']
# Out:
# [{u'name': u'#PeopleWhoMadeMy2014',
#   u'promoted_content': None,
#   u'query': u'%23PeopleWhoMadeMy2014',
#   u'url': u'http://twitter.com/search?q=%23PeopleWhoMadeMy2014'},
#  {u'name': u'#\xd6zg\xfcrBelaParalelSusacak',
#   u'promoted_content': None,
#   u'query': u'%23%C3%96zg%C3%BCrBelaParalelSusacak',
#   u'url': u'http://twitter.com/search?q=%23%C3%96zg%C3%BCrBelaParalelSusacak'},
#  {u'name': u'#AyatRejectKejam',
#   u'promoted_content': None,
#   u'query': u'%23AyatRejectKejam',
#   u'url': u'http://twitter.com/search?q=%23AyatRejectKejam'},
#  {u'name': u'#ZamanTemizlikZaman\u0131',
#   u'promoted_content': None,
#   u'query': u'%23ZamanTemizlikZaman%C4%B1',
#   u'url': u'http://twitter.com/search?q=%23ZamanTemizlikZaman%C4%B1'},
#  {u'name': u'#RoIndiaRo',
#   u'promoted_content': None,
#   u'query': u'%23RoIndiaRo',
#   u'url': u'http://twitter.com/search?q=%23RoIndiaRo'},
#  {u'name': u'El Arabi',
#   u'promoted_content': None,
#   u'query': u'%22El+Arabi%22',
#   u'url': u'http://twitter.com/search?q=%22El+Arabi%22'},
#  {u'name': u'JaDine BLUEming Loveteam',
#   u'promoted_content': None,
#   u'query': u'%22JaDine+BLUEming+Loveteam%22',
#   u'url': u'http://twitter.com/search?q=%22JaDine+BLUEming+Loveteam%22'},
#  {u'name': u'Juventus 1-0 Sampdoria',
#   u'promoted_content': None,
#   u'query': u'%22Juventus+1-0+Sampdoria%22',
#   u'url': u'http://twitter.com/search?q=%22Juventus+1-0+Sampdoria%22'},
#  {u'name': u'Ekrem',
#   u'promoted_content': None,
#   u'query': u'Ekrem',
#   u'url': u'http://twitter.com/search?q=Ekrem'},
#  {u'name': u'Ne\u015fe D\xfczel',
#   u'promoted_content': None,
#   u'query': u'%22Ne%C5%9Fe+D%C3%BCzel%22',
#   u'url': u'http://twitter.com/search?q=%22Ne%C5%9Fe+D%C3%BCzel%22'}]

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

seoul_trends_set = set([trend['name'] 
                     for trend in seoul_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'#PeopleWhoMadeMy2014'])

# %%
print seoul_trends_set
# Out:
# set([u'\ud5c8\uadf8\ub370\uc774', u'\uc0dd\uc77c\ucd95\ud558', u'#\uc790\uce90\uac00_\ub208_\uc624\ub294\ub0a0_\ud558\ub294\uc77c', u'\uae40\uc6b0\ube48', u'\uc774\ud604\uc6b0', u'\ub7f0\ub2dd\ub9e8', u'\ub3d9\uacf5\uc9c0\uc9c4', u'#\uc6b0\ub9ac\uc7a5\ub974_\uba85\ub300\uc0ac', u'#\ud0d0\ub77c\ubc30_\uac70\uc9d3\ub9d0_\ub300\uc804', u'\ucd5c\uacbd\uc704'])

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#PeopleWhoMadeMy2014' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...

print json.dumps(statuses[0], indent=1)
# Out:
# Length of statuses 100
# Length of statuses
#  200
# Length of statuses
#  200
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @korean_rps: #PeopleWhoMadeMy2014 semua member KRPS \u2665\u2665\u2665 -bimin",
#  "in_reply_to_status_id": null,
#  "id": 544111310389006337,
#  "favorite_count": 0,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 2874659641,
#     "indices": [
#      3,
#      14
#     ],
#     "id_str": "2874659641",
#     "screen_name": "korean_rps",
#     "name": "KRPS\u2727"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      16,
#      36
#     ],
#     "text": "PeopleWhoMadeMy2014"
#    }
#   ],
#   "urls": []
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 5,
#  "id_str": "544111310389006337",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "#PeopleWhoMadeMy2014 semua member KRPS \u2665\u2665\u2665 -bimin",
#   "in_reply_to_status_id": null,
#   "id": 544110024214052865,
#   "favorite_count": 2,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       0,
#       20
#      ],
#      "text": "PeopleWhoMadeMy2014"
#     }
#    ],
#    "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 5,
#   "id_str": "544110024214052865",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "profile_text_color": "000000",
#    "default_profile_image": false,
#    "id": 2874659641,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/538008362919534593/rRci01aS.png",
#    "verified": false,
#    "profile_location": null,
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/539049916710940672/-FzT4rC-_normal.jpeg",
#    "profile_sidebar_fill_color": "000000",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/dPFcmG4dQV",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://koreanrps.weebly.com",
#        "display_url": "koreanrps.weebly.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 173,
#    "profile_sidebar_border_color": "000000",
#    "id_str": "2874659641",
#    "profile_background_color": "000000",
#    "listed_count": 0,
#    "is_translation_enabled": false,
#    "utc_offset": 25200,
#    "statuses_count": 4201,
#    "description": "Open Agency K-star only. Free uname and fix dn. No twin. Check our weebly before join ^^. [O] Bimin [A] Rinbae Yuko Yong Chan",
#    "friends_count": 120,
#    "location": "Join grup wa? DM!^^",
#    "profile_link_color": "DD2E44",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/539049916710940672/-FzT4rC-_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2874659641/1418460343",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/538008362919534593/rRci01aS.png",
#    "name": "KRPS\u2727",
#    "lang": "en",
#    "profile_background_tile": true,
#    "favourites_count": 442,
#    "screen_name": "korean_rps",
#    "notifications": false,
#    "url": "http://t.co/dPFcmG4dQV",
#    "created_at": "Fri Oct 24 05:27:01 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": "Jakarta",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "lang": "in",
#   "created_at": "Sun Dec 14 12:41:53 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "in",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "profile_use_background_image": true,
#   "profile_text_color": "362720",
#   "default_profile_image": false,
#   "id": 1099834897,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/543304321442406400/XtoK0SAo.jpeg",
#   "verified": false,
#   "profile_location": null,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/543999845183143936/SZv2IMCO_normal.jpeg",
#   "profile_sidebar_fill_color": "E5507E",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/74zg0HgbMJ",
#       "indices": [
#        0,
#        22
#       ],
#       "expanded_url": "http://cafe.daum.net/aceofangels",
#       "display_url": "cafe.daum.net/aceofangels"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 1440,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "1099834897",
#   "profile_background_color": "ABB8C2",
#   "listed_count": 1,
#   "is_translation_enabled": false,
#   "utc_offset": 25200,
#   "statuses_count": 8649,
#   "description": "(( \ubd07 )) 7/8 \uc5d4\uc824\uc2a4\u2014AOA (\uc5d0\uc774 \uc624\uc5d0\uc774)'s \ud050\ud2f0 \ub9c9\ub0b4\u2014\uae40\ucc2c\ubbf8\u20141996\ub144 06\uc6d4 19\uc77c!\u2014 (1128) @CClown_Rome90's \u2014krps;derm\u2014 #FNCFams #AOAHeaven",
#   "friends_count": 1207,
#   "location": "seoul, kr",
#   "profile_link_color": "9266CC",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/543999845183143936/SZv2IMCO_normal.jpeg",
#   "following": false,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1099834897/1418304180",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/543304321442406400/XtoK0SAo.jpeg",
#   "name": "dermbabyday \u2727 ",
#   "lang": "en",
#   "profile_background_tile": true,
#   "favourites_count": 132,
#   "screen_name": "aoaxchan",
#   "notifications": false,
#   "url": "http://t.co/74zg0HgbMJ",
#   "created_at": "Fri Jan 18 02:36:19 +0000 2013",
#   "contributors_enabled": false,
#   "time_zone": "Jakarta",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "lang": "in",
#  "created_at": "Sun Dec 14 12:47:00 +0000 2014",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "in",
#   "result_type": "recent"
#  }
# }

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
q = '#PeopleWhoMadeMy2014' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

for status in statuses:
    print status['text']
# Out:
# #PeopleWhoMadeMy2014 @clarawinslet
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @phanfair @pxdilla @patriciamigos @nebulocked @spirit_phanimal @phankjellberg @smoshykatycat @pewdiepah_
# RT @teacupirwinx: #PeopleWhoMadeMy2014 @MxllyBarnes @itsirwinstyles @5SOS @onedirection @TheVampsband @ollyofficial 😌😺❤️
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @JIIEYEON: #PeopleWhoMadeMy2014 sq tercintah  @yvragirls @baesujeyyy @kryshtx @sumnier @ervewen @sowjune ♡🎉
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014
# @itscrismalik
# RT @outliercupcake: #PeopleWhoMadeMy2014 @MaryJrNation88 @cater007 @DaryllM_13 @Insomnivic @itsDevT82 @IaNaTion @AVD31 @NattieBroskette
# RT @Capucine8m: @TPMPchildrens @Miss_Tack @Taison_Maeda @MyTPMPef @MyMEDIASef @PEmique @givemeradio @ClaireRenault @TeamEnoMalagre #PeopleW…
# #PeopleWhoMadeMy2014 mes rencontres twitter dont lilia, adélaide, nawel, chloé,...&lt;3 ily&lt;3
# RT @toxickidhes: #PeopleWhoMadeMy2014
# @niallspetal
# http://t.co/9d1Rov3RYG #PeopleWhoMadeMy2014 http://t.co/J6ytIWH3Xb
# #PeopleWhoMadeMy2014 coojung sese gesoy xochan bangbay cejyo kimoy wenwen bamin choet pidy kikis thank's
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @myworldaniston u made my year &amp; you know it.So happy we finally got to meet,u mean a lot to me💗 http://t.co/5AH9GyU3mX
# RT @glenndung: #PeopleWhoMadeMy2014 @Tintinrintinrin @imjonicabuenafe @PEARLitaaa @katepepz insert penya insert rose
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @HeyItsTalaa
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @1DLittleSecret: #PeopleWhoMadeMy2014 @Louis_Tomlinson @Real_Liam_Payne @Harry_Styles @zaynmalik @NiallOfficial 💕🙊
# RT @bangtanoiado: #PeopleWhoMadeMy2014 o cara que eu não consigo xingar @guaxiumin
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @asyIumlourry: @ljpftgarrix !! #PeopleWhoMadeMy2014
# #PeopleWhoMadeMy2014 @canadianfthemmo.
# RT @1DLittleSecret: #PeopleWhoMadeMy2014 @Louis_Tomlinson @Real_Liam_Payne @Harry_Styles @zaynmalik @NiallOfficial 💕🙊
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @xdimpleofstyles
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @intorejects: @bandanafi @irwinchance @mikesfits @rudesexmichael no me acuerdo de más matarme :( #PeopleWhoMadeMy2014
# ily meciw♡"@klirstal_: #peoplewhomademy2014 mey?!cayang @BERBIEP"
# RT @holtackles: #PeopleWhoMadeMy2014 @holtsbreva @LittleHopeM @littlewolfies_ @AMELLSRICKARDSS @90srickards @rodensackles @deanwithpie @hip…
# "@terminxtor: "blackwhitc: #PeopleWhoMadeMy2014 terong @terminxtor =))"duileh=)"wuahuhahuha=)
# #peoplewhomademy2014 😘 😘 😘  oppa @CS_minhyuk90
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @5SXSFAMILY: #PeopleWhoMadeMy2014
# 🌸 Вэй
# 🌸 Элла
# 🌸 Кемч
# 🌸 Антон
# 🌸 Доран
# 🌸 Бо
# 🌸 Грант
# 🌸 Анита
# 🌸 Карина
#
# Без вас я бы не смог.
# #PeopleWhoMadeMy2014 @antiia14 @Aaaaadri11 @barriosesamo10
# #PeopleWhoMadeMy2014 ну ладно, я подключусь
# #PeopleWhoMadeMy2014 thank you for being part of my 2014 ; sana maging part ka din mg 2015 ko and so on. I love you byyy. 😁😙💕 @__minjoon
# #PeopleWhoMadeMy2014 adek tersarap -_- @_seulgi10
# RT @OfficialFiftyPH: #PeopleWhoMadeMy2014 @2cuteaurora Thank you sweetie for always giving me an #FF Have a nice day 😘 ❤
# GateCrashers. &lt;3
#  @TriciaGoingco @czarina_BYE @imjenkabe @_stupiditae @HunHanCouple94 @liudaeIGOP17  #PeopleWhoMadeMy2014
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 #USTR0LIT4$ ♡
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @ghel11ghel98
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @CynaHoran_xx  @JSharmaine21  @allisonxcvr  @EuniAnn  @aubrey_linette  @tielsea
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @Alaizaaaaa the best bestfriend goes to you! 💋 luv u trayds.
# #PeopleWhoMadeMy2014 @India_Crone :)
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @dallasofnarry
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @soulmalikk gracias por tanto en tan poco tiempo, te quiero Zaynchu
# #PeopleWhoMadeMy2014 @evaborr99
# #PeopleWhoMadeMy2014 @5SOS &lt;3
# RT @staliws: #PeopleWhoMadeMy2014 @Kty_FR @krystaljsjsj tetep jadi triokresek yoyo!mwc http://t.co/Q7Hgb31YKN
# #PeopleWhoMadeMy2014 omg @onedirection @Real_Liam_Payne @Harry_Styles @zaynmalik @Louis_Tomlinson @NiallOfficial
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 My Familyyyyy
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# @angelagerda @RacikAnn @ireniusdlyon @lydiahellen @ariefrieff @argaclaud they always here to be with me and others also #PeopleWhoMadeMy2014
# #PeopleWhoMadeMy2014 Yiii love you! 😘💕💘😍 http://t.co/CsdwW0jDZ0
# RT @ffslukeyb: #PeopleWhoMadeMy2014 @givemebeau_ @OMFGYAMMOUNI @omfgskip @pussybitchluke @janocanunot @rockingwithluke @mewmewbeau @jai4pre…
# #PeopleWhoMadeMy2014 @xnicnik :* xx
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 Bestie yg otaknya agak gesrek @junsoejun 💋
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 OHI YG SUKA NGATAIN AKU SURUH TOBAT @Seulghii
# when @chenloves1d followed me.thank you so much:) #PeopleWhoMadeMy2014
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @hustlernarry: #PeopleWhoMadeMy2014
#
# @hurrehstiles
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @MartaEndless_28: #PeopleWhoMadeMy2014 es increíble lo que esta familia me llega a emocionar,lo que se les llega a querer @RQAGalicia gr…
# RT @camdallasangel: #PeopleWhoMadeMy2014
# @Caaarolina11
# @poeticdallas
# @Iauraine
# @lmfa0cameron
# @DamnCam21
# @TwerkOnCameron
# @CrushOnCame…
# #PeopleWhoMadeMy2014 какаду
# 20. mis pelusas en general♡ #peoplewhomademy2014
# #PeopleWhoMadeMy2014 @miyorns ajunekk🙆
# RT @keilovevyz: @yeojakr #Peoplewhomademy2014 mamih keilo kangen 😔wlpun jrng kontekan ttp klo ada apa apa ngomong ya maapin keilo klo keilo…
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 @kidrauhlfavs 💖💖
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @YGHI96: #PeopleWhoMadeMy2014 @KF_Taeyong smelly!
# RT @Angus_OL: #PeopleWhoMadeMy2014
#
# ME
# #PeopleWhoMadeMy2014 @trouble_makerme
# RT @yourwronglove: #PeopleWhoMadeMy2014 @KindasCraziesJB
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @MonaAbitona: #PeopleWhoMadeMy2014 @IamDheannaG ❤️
# #PeopleWhoMadeMy2014 @beaabratique @shanetlntn 💙
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# RT @nasshftniall: @suckmypaynes #PeopleWhoMadeMy2014 💘💘
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…
# #PeopleWhoMadeMy2014 no fucking one.

# %%
statuses[1]['text']
# Out:
# u'RT @drissawaked: #LosAngeles \n#PeopleWhoMadeMy2014\n#AskNacks\n#TeletonUSA\n#UFCPhoenix\n#TimBradley\n#TheU\n#Santa\n#Mariota\n#TopFive #LA http://\u2026'

# %%
search_results['search_metadata']['next_results'][1:].split("&")
# Out:
# [u'max_id=470032624761982975',
#  u'q=%23MakeASongDepressing',
#  u'count=100',
#  u'include_entities=1']

# %%
top = statuses[0]
for status in statuses:
    if status['retweet_count']>top['retweet_count']:
        top=status
        
print top['retweet_count']
print top['text']
# Out:
# 3371
# RT @drissawaked: #LosAngeles
# #PeopleWhoMadeMy2014
# #AskNacks
# #TeletonUSA
# #UFCPhoenix
# #TimBradley
# #TheU
# #Santa
# #Mariota
# #TopFive #LA http://…

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print t['retweet_count']
print t['retweeted_status']

# Can you find the most retweeted tweet in your search results? Try do do it!
# Out:
# 23
# {u'contributors': None, u'truncated': False, u'text': u'#MentionSomeoneImportantForYou God.', u'in_reply_to_status_id': None, u'id': 316944833233186816L, u'favorite_count': 0, u'source': u'web', u'retweeted': False, u'coordinates': None, u'entities': {u'user_mentions': [], u'hashtags': [{u'indices': [0, 30], u'text': u'MentionSomeoneImportantForYou'}], u'urls': []}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 23, u'id_str': u'316944833233186816', u'favorited': False, u'user': {u'follow_request_sent': None, u'profile_use_background_image': True, u'id': 56259379, u'verified': False, u'profile_text_color': u'3C3940', u'profile_image_url_https': u'https://si0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', u'profile_sidebar_fill_color': u'95E8EC', u'is_translator': False, u'geo_enabled': True, u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/yRX89YM4J0', u'indices': [0, 22], u'expanded_url': u'http://www.datpiff.com/mixtapes-detail.php?id=470069', u'display_url': u'datpiff.com/mixtapes-detai\u2026'}]}, u'description': {u'urls': []}}, u'followers_count': 105041, u'protected': False, u'location': u'', u'default_profile_image': False, u'id_str': u'56259379', u'utc_offset': -18000, u'statuses_count': 16691, u'description': u'#TheseAreTheWordsISaid LP', u'friends_count': 59615, u'profile_link_color': u'91785A', u'profile_image_url': u'http://a0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', u'notifications': None, u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', u'profile_background_color': u'000000', u'profile_banner_url': u'https://si0.twimg.com/profile_banners/56259379/1363388572', u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', u'name': u'Download the NEW LP!', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 6142, u'screen_name': u'hassanmusician', u'url': u'http://t.co/yRX89YM4J0', u'created_at': u'Mon Jul 13 02:18:25 +0000 2009', u'contributors_enabled': False, u'time_zone': u'Eastern Time (US & Canada)', u'profile_sidebar_border_color': u'000000', u'default_profile': False, u'following': None, u'listed_count': 64}, u'geo': None, u'in_reply_to_user_id_str': None, u'lang': u'en', u'created_at': u'Wed Mar 27 16:08:31 +0000 2013', u'in_reply_to_status_id_str': None, u'place': None, u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'}}

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print "status texts"
print json.dumps(status_texts[0:5], indent=1)
print "\n"
print "screen names"
print json.dumps(screen_names[0:5], indent=1) 
print "\n"
print "hash tags"
print json.dumps(hashtags[0:5], indent=1)
print "\n"
print "words"
print json.dumps(words[0:5], indent=1)
# Out:
# status texts
# [
#  "\u201c@KathleenMariee_: #MentionSomeOneImportantForYou @AhhlicksCruise , @itsravennn_cx ,@kandykisses_13 , @BMOLOGY\u201d\ud83d\udc4d",
#  "#MentionSomeoneImportantForYou My bf @Linkin_Sunrise.",
#  "RT @hassanmusician: #MentionSomeoneImportantForYou God.",
#  "#MentionSomeoneImportantForYou @Louis_Tomlinson",
#  "#MentionSomeoneImportantForYou @Delta_Universe"
# ]
#
#
# screen names
# [
#  "KathleenMariee_",
#  "AhhlicksCruise",
#  "itsravennn_cx",
#  "kandykisses_13",
#  "BMOLOGY"
# ]
#
#
# hash tags
# [
#  "MentionSomeOneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou"
# ]
#
#
# words
# [
#  "\u201c@KathleenMariee_:",
#  "#MentionSomeOneImportantForYou",
#  "@AhhlicksCruise",
#  ",",
#  "@itsravennn_cx"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print
# Out:
# [(u'#MentionSomeoneImportantForYou', 92), (u'RT', 34), (u'my', 10), (u',', 6), (u'@justinbieber', 6), (u'&lt;3', 6), (u'My', 5), (u'and', 4), (u'I', 4), (u'te', 3)]
#
# [(u'justinbieber', 6), (u'Kid_Charliej', 2), (u'Cavillafuerte', 2), (u'touchmestyles_', 1), (u'aliceorr96', 1), (u'gymleeam', 1), (u'fienas', 1), (u'nayely_1D', 1), (u'angelchute', 1), (u'BigTittieAngel', 1)]
#
# [(u'MentionSomeoneImportantForYou', 94), (u'mentionsomeoneimportantforyou', 3), (u'NoHomo', 1), (u'Love', 1), (u'MentionSomeOneImportantForYou', 1), (u'MyHeart', 1), (u'bebesito', 1)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# +--------------------------------+-------+
# | Word                           | Count |
# +--------------------------------+-------+
# | #MentionSomeoneImportantForYou |    92 |
# | RT                             |    34 |
# | my                             |    10 |
# | ,                              |     6 |
# | @justinbieber                  |     6 |
# | &lt;3                          |     6 |
# | My                             |     5 |
# | and                            |     4 |
# | I                              |     4 |
# | te                             |     3 |
# +--------------------------------+-------+
# +----------------+-------+
# | Screen Name    | Count |
# +----------------+-------+
# | justinbieber   |     6 |
# | Kid_Charliej   |     2 |
# | Cavillafuerte  |     2 |
# | touchmestyles_ |     1 |
# | aliceorr96     |     1 |
# | gymleeam       |     1 |
# | fienas         |     1 |
# | nayely_1D      |     1 |
# | angelchute     |     1 |
# | BigTittieAngel |     1 |
# +----------------+-------+
# +-------------------------------+-------+
# | Hashtag                       | Count |
# +-------------------------------+-------+
# | MentionSomeoneImportantForYou |    94 |
# | mentionsomeoneimportantforyou |     3 |
# | NoHomo                        |     1 |
# | Love                          |     1 |
# | MentionSomeOneImportantForYou |     1 |
# | MyHeart                       |     1 |
# | bebesito                      |     1 |
# +-------------------------------+-------+

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print lexical_diversity(words)
print lexical_diversity(screen_names)
print lexical_diversity(hashtags)
print average_words(status_texts)
# Out:
# 0.67610619469
# 0.955414012739
# 0.0686274509804
# 5.76530612245

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if status.has_key('retweeted_status')
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print pt
# Out:
# +-------+----------------+----------------------------------------------------+
# | Count | Screen Name    | Text                                               |
# +-------+----------------+----------------------------------------------------+
# | 23    | hassanmusician | RT @hassanmusician: #MentionSomeoneImportantForYou |
# |       |                | God.                                               |
# | 21    | HSweethearts   | RT @HSweethearts: #MentionSomeoneImportantForYou   |
# |       |                | my high school sweetheart ❤💋                      |
# | 15    | LosAlejandro_  | RT @LosAlejandro_: ¿Nadie te menciono en           |
# |       |                | "#MentionSomeoneImportantForYou"? JAJAJAJAJAJAJAJA |
# |       |                | JAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJA Ven, ...  |
# | 9     | SCOTTSUMME     | RT @SCOTTSUMME: #MentionSomeoneImportantForYou My  |
# |       |                | Mum. Shes loving, caring, strong, all in one. I    |
# |       |                | love her so much ❤❤❤❤                              |
# | 7     | degrassihaha   | RT @degrassihaha: #MentionSomeoneImportantForYou I |
# |       |                | can't put every Degrassi cast member, crew member, |
# |       |                | and writer in just one tweet....                   |
# +-------+----------------+----------------------------------------------------+

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print [r['user']['screen_name'] for r in _retweets]
# Out:
# [u'jyeee', u'Ceejaynatics', u'Majendalove', u'shameeennnn', u'EmilyearoRuiz', u'Oliviyaaay', u'ShikaynaAryan', u'LoveKyana18', u'iiaamcamille', u'figueroangelene', u'Aileenylalalove', u'mikaachuu', u'kidamgos', u'ShaaaronOng', u'asdfghjbl']

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-a16b44257ee0> in <module>()
#       3 word_counts = sorted(Counter(words).values(), reverse=True)
#       4
# ----> 5 plt.loglog(word_counts)
#       6 plt.ylabel("Freq")
#       7 plt.xlabel("Word Rank")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print counts
# Out:
# [2, 6, 13, 93, 2, 68, 4, 68, 5, 1, 35, 38, 21, 21, 7, 289, 6, 93, 2, 20, 13, 18, 270, 36, 100, 1, 10, 3, 7, 1, 2, 4, 18, 84, 258, 1, 65, 489, 35, 429, 39, 249, 10, 1, 161, 93, 2, 3, 25, 57, 62, 7, 31, 8, 219, 2, 36, 78, 18, 3, 8, 8, 501, 17, 7, 1, 93, 68, 18, 1, 65, 128, 4, 7, 99, 1, 42, 62, 57, 18, 219, 11, 1, 25, 19, 511, 10, 86, 3, 128, 3, 2, 780, 8, 38, 20, 1, 378, 4, 6, 46, 18, 5, 4, 38, 407, 9, 1, 501, 14, 74, 47, 18, 3, 58, 74, 6, 93, 180, 57, 29, 26, 20, 18, 18, 58, 65, 293, 91, 100, 225, 5, 180, 6, 2, 46, 3, 149, 140, 21, 21, 36, 21, 20, 3]

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(log(counts))
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print log(counts)
# Out:
# [ 0.69314718  1.79175947  2.56494936  4.53259949  0.69314718  4.21950771
#   1.38629436  4.21950771  1.60943791  0.          3.55534806  3.63758616
#   3.04452244  3.04452244  1.94591015  5.66642669  1.79175947  4.53259949
#   0.69314718  2.99573227  2.56494936  2.89037176  5.59842196  3.58351894
#   4.60517019  0.          2.30258509  1.09861229  1.94591015  0.
#   0.69314718  1.38629436  2.89037176  4.4308168   5.55295958  0.
#   4.17438727  6.19236249  3.55534806  6.06145692  3.66356165  5.5174529
#   2.30258509  0.          5.08140436  4.53259949  0.69314718  1.09861229
#   3.21887582  4.04305127  4.12713439  1.94591015  3.4339872   2.07944154
#   5.38907173  0.69314718  3.58351894  4.35670883  2.89037176  1.09861229
#   2.07944154  2.07944154  6.2166061   2.83321334  1.94591015  0.
#   4.53259949  4.21950771  2.89037176  0.          4.17438727  4.85203026
#   1.38629436  1.94591015  4.59511985  0.          3.73766962  4.12713439
#   4.04305127  2.89037176  5.38907173  2.39789527  0.          3.21887582
#   2.94443898  6.23636959  2.30258509  4.4543473   1.09861229  4.85203026
#   1.09861229  0.69314718  6.65929392  2.07944154  3.63758616  2.99573227
#   0.          5.9348942   1.38629436  1.79175947  3.8286414   2.89037176
#   1.60943791  1.38629436  3.63758616  6.00881319  2.19722458  0.          6.2166061
#   2.63905733  4.30406509  3.8501476   2.89037176  1.09861229  4.06044301
#   4.30406509  1.79175947  4.53259949  5.19295685  4.04305127  3.36729583
#   3.25809654  2.99573227  2.89037176  2.89037176  4.06044301  4.17438727
#   5.68017261  4.51085951  4.60517019  5.4161004   1.60943791  5.19295685
#   1.79175947  0.69314718  3.8286414   1.09861229  5.00394631  4.94164242
#   3.04452244  3.04452244  3.58351894  3.04452244  2.99573227  1.09861229]
